# %% [markdown]
# # Vectorizing Text and Transformations and n-grams
# In the previous lab, we’ve seen how we clean our data before starting processing it. In this lab we’ll introduce the data structures largely used in text analysis involving machine learning techniques – vectors.
#
# We'll see the bag of words model, TF-IDF and build N-grams on the NLTK gutenberg corpus.

# %%
# Imports
from nltk.corpus import gutenberg
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim import corpora, models
import gensim
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# we chose some of the texts available on the NLTK gutenberg corpus which constitutes of english litterature novels.
text_names = ["austen-emma.txt", 
              "shakespeare-macbeth.txt" ,
              "shakespeare-hamlet.txt",
              "chesterton-ball.txt"]  

documents = []

# we create a list of our custom stopwords
my_stop_words = [u'say', u'\'s', u'Mr', u'be', u'said', u'says', u'saying', u'would',  u'could']

# we do some preprocessing on our corpus, which includes the tokenization, lower casing, 
# removal of spacy stopwords and our custom stopwords, removal of punctuation and special characters.
for text_name in text_names:
    text = gutenberg.raw(text_name)
    tokens = word_tokenize(text)
    filtered_tokens = [token.lower() for token in tokens if token.lower() not in stopwords.words('english') and token.isalpha() and token.lower() not in my_stop_words]
    doc = nlp(" ".join(filtered_tokens))
    lemmatized_tokens = [token.lemma_ for token in doc]
    
    documents.append(lemmatized_tokens)

# %%
# create a dictionary of our corpus
dictionary = corpora.Dictionary(documents)
# save the dictionary in a txt file
dictionary.save_as_text("old_dictionary.txt")
print(len(dictionary))
# Out:
# 12250

# %%
# transform the corpus into a bag of words dictionary
corpus = [dictionary.doc2bow(doc) for doc in documents]
corpus
# Out:
# [[(0, 24),
#   (1, 1),
#   (2, 1),
#   (3, 2),
#   (4, 1),
#   (5, 3),
#   (6, 71),
#   (7, 1),
#   (8, 1),
#   (9, 7),
#   (10, 8),
#   (11, 3),
#   (12, 5),
#   (13, 1),
#   (14, 16),
#   (15, 10),
#   (16, 1),
#   (17, 2),
#   (18, 4),
#   (19, 33),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 3),
#   (24, 5),
#   (25, 1),
#   (26, 1),
#   (27, 2),
#   (28, 1),
#   (29, 1),
#   (30, 6),
#   (31, 28),
#   (32, 8),
#   (33, 2),
#   (34, 1),
#   (35, 1),
#   (36, 3),
#   (37, 2),
#   (38, 2),
#   (39, 8),
#   (40, 1),
#   (41, 9),
#   (42, 11),
#   (43, 2),
#   (44, 3),
#   (45, 6),
#   (46, 1),
#   (47, 4),
#   (48, 1),
#   (49, 60),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 2),
#   (54, 1),
#   (55, 2),
#   (56, 1),
#   (57, 1),
#   (58, 2),
#   (59, 1),
#   (60, 31),
#   (61, 6),
#   (62, 26),
#   (63, 63),
#   (64, 7),
#   (65, 1),
#   (66, 5),
#   (67, 4),
#   (68, 2),
#   (69, 7),
#   (70, 1),
#   (71, 1),
#   (72, 7),
#   (73, 1),
#   (74, 25),
#   (75, 1),
#   (76, 7),
#   (77, 7),
#   (78, 4),
#   (79, 3),
#   (80, 29),
#   (81, 2),
#   (82, 1),
#   (83, 2),
#   (84, 49),
#   (85, 10),
#   (86, 4),
#   (87, 23),
#   (88, 2),
#   (89, 2),
#   (90, 1),
#   (91, 1),
#   (92, 1),
#   (93, 6),
#   (94, 2),
#   (95, 3),
#   (96, 1),
#   (97, 24),
#   (98, 27),
#   (99, 2),
#   (100, 5),
#   (101, 2),
#   (102, 1),
#   (103, 24),
#   (104, 4),
#   (105, 1),
#   (106, 2),
#   (107, 2),
#   (108, 7),
#   (109, 2),
#   (110, 39),
#   (111, 1),
#   (112, 3),
#   (113, 1),
#   (114, 1),
#   (115, 1),
#   (116, 14),
#   (117, 2),
#   (118, 16),
#   (119, 1),
#   (120, 1),
#   (121, 3),
#   (122, 1),
#   (123, 1),
#   (124, 10),
#   (125, 1),
#   (126, 13),
#   (127, 2),
#   (128, 3),
#   (129, 60),
#   (130, 9),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 2),
#   (135, 2),
#   (136, 16),
#   (137, 1),
#   (138, 2),
#   (139, 1),
#   (140, 65),
#   (141, 6),
#   (142, 41),
#   (143, 24),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 4),
#   (148, 8),
#   (149, 16),
#   (150, 31),
#   (151, 2),
#   (152, 42),
#   (153, 50),
#   (154, 2),
#   (155, 5),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 48),
#   (160, 1),
#   (161, 2),
#   (162, 1),
#   (163, 2),
#   (164, 1),
#   (165, 53),
#   (166, 1),
#   (167, 3),
#   (168, 2),
#   (169, 3),
#   (170, 1),
#   (171, 24),
#   (172, 2),
#   (173, 4),
#   (174, 4),
#   (175, 1),
#   (176, 3),
#   (177, 4),
#   (178, 7),
#   (179, 3),
#   (180, 1),
#   (181, 4),
#   (182, 8),
#   (183, 89),
#   (184, 4),
#   (185, 5),
#   (186, 3),
#   (187, 3),
#   (188, 3),
#   (189, 1),
#   (190, 4),
#   (191, 2),
#   (192, 88),
#   (193, 26),
#   (194, 4),
#   (195, 8),
#   (196, 2),
#   (197, 1),
#   (198, 1),
#   (199, 44),
#   (200, 23),
#   (201, 1),
#   (202, 7),
#   (203, 2),
#   (204, 2),
#   (205, 2),
#   (206, 1),
#   (207, 23),
#   (208, 238),
#   (209, 4),
#   (210, 4),
#   (211, 4),
#   (212, 2),
#   (213, 2),
#   (214, 4),
#   (215, 1),
#   (216, 35),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 6),
#   (221, 1),
#   (222, 51),
#   (223, 3),
#   (224, 6),
#   (225, 6),
#   (226, 2),
#   (227, 28),
#   (228, 13),
#   (229, 6),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 5),
#   (234, 7),
#   (235, 1),
#   (236, 19),
#   (237, 6),
#   (238, 2),
#   (239, 6),
#   (240, 1),
#   (241, 3),
#   (242, 16),
#   (243, 1),
#   (244, 112),
#   (245, 92),
#   (246, 1),
#   (247, 1),
#   (248, 7),
#   (249, 4),
#   (250, 1),
#   (251, 19),
#   (252, 31),
#   (253, 6),
#   (254, 1),
#   (255, 15),
#   (256, 3),
#   (257, 3),
#   (258, 1),
#   (259, 3),
#   (260, 13),
#   (261, 1),
#   (262, 1),
#   (263, 10),
#   (264, 4),
#   (265, 4),
#   (266, 102),
#   (267, 34),
#   (268, 1),
#   (269, 2),
#   (270, 1),
#   (271, 1),
#   (272, 2),
#   (273, 17),
#   (274, 1),
#   (275, 1),
#   (276, 6),
#   (277, 7),
#   (278, 1),
#   (279, 1),
#   (280, 2),
#   (281, 7),
#   (282, 7),
#   (283, 4),
#   (284, 1),
#   (285, 19),
#   (286, 21),
#   (287, 2),
#   (288, 2),
#   (289, 18),
#   (290, 1),
#   (291, 3),
#   (292, 7),
#   (293, 2),
#   (294, 1),
#   (295, 2),
#   (296, 1),
#   (297, 6),
#   (298, 1),
#   (299, 1),
#   (300, 12),
#   (301, 1),
#   (302, 15),
#   (303, 1),
#   (304, 13),
#   (305, 16),
#   (306, 18),
#   (307, 1),
#   (308, 13),
#   (309, 27),
#   (310, 3),
#   (311, 1),
#   (312, 3),
#   (313, 2),
#   (314, 1),
#   (315, 6),
#   (316, 1),
#   (317, 2),
#   (318, 1),
#   (319, 2),
#   (320, 4),
#   (321, 1),
#   (322, 1),
#   (323, 3),
#   (324, 27),
#   (325, 4),
#   (326, 92),
#   (327, 1),
#   (328, 1),
#   (329, 2),
#   (330, 3),
#   (331, 1),
#   (332, 1),
#   (333, 1),
#   (334, 2),
#   (335, 1),
#   (336, 4),
#   (337, 4),
#   (338, 3),
#   (339, 1),
#   (340, 21),
#   (341, 14),
#   (342, 1),
#   (343, 5),
#   (344, 1),
#   (345, 5),
#   (346, 13),
#   (347, 76),
#   (348, 1),
#   (349, 4),
#   (350, 7),
#   (351, 5),
#   (352, 1),
#   (353, 1),
#   (354, 5),
#   (355, 2),
#   (356, 2),
#   (357, 1),
#   (358, 2),
#   (359, 29),
#   (360, 2),
#   (361, 49),
#   (362, 9),
#   (363, 1),
#   (364, 1),
#   (365, 32),
#   (366, 31),
#   (367, 4),
#   (368, 1),
#   (369, 87),
#   (370, 10),
#   (371, 3),
#   (372, 1),
#   (373, 3),
#   (374, 1),
#   (375, 1),
#   (376, 9),
#   (377, 2),
#   (378, 3),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 2),
#   (383, 3),
#   (384, 4),
#   (385, 56),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 2),
#   (390, 6),
#   (391, 7),
#   (392, 3),
#   (393, 2),
#   (394, 6),
#   (395, 22),
#   (396, 1),
#   (397, 1),
#   (398, 2),
#   (399, 1),
#   (400, 26),
#   (401, 137),
#   (402, 2),
#   (403, 12),
#   (404, 6),
#   (405, 1),
#   (406, 15),
#   (407, 6),
#   (408, 65),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 93),
#   (413, 1),
#   (414, 1),
#   (415, 3),
#   (416, 7),
#   (417, 1),
#   (418, 1),
#   (419, 34),
#   (420, 4),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 2),
#   (425, 4),
#   (426, 2),
#   (427, 2),
#   (428, 5),
#   (429, 2),
#   (430, 1),
#   (431, 1),
#   (432, 1),
#   (433, 1),
#   (434, 5),
#   (435, 2),
#   (436, 5),
#   (437, 121),
#   (438, 24),
#   (439, 5),
#   (440, 20),
#   (441, 2),
#   (442, 2),
#   (443, 1),
#   (444, 3),
#   (445, 68),
#   (446, 2),
#   (447, 3),
#   (448, 1),
#   (449, 1),
#   (450, 24),
#   (451, 3),
#   (452, 32),
#   (453, 1),
#   (454, 1),
#   (455, 48),
#   (456, 1),
#   (457, 2),
#   (458, 12),
#   (459, 4),
#   (460, 2),
#   (461, 23),
#   (462, 2),
#   (463, 1),
#   (464, 143),
#   (465, 5),
#   (466, 1),
#   (467, 15),
#   (468, 24),
#   (469, 1),
#   (470, 18),
#   (471, 2),
#   (472, 3),
#   (473, 3),
#   (474, 2),
#   (475, 152),
#   (476, 2),
#   (477, 3),
#   (478, 27),
#   (479, 4),
#   (480, 5),
#   (481, 1),
#   (482, 7),
#   (483, 3),
#   (484, 7),
#   (485, 4),
#   (486, 2),
#   (487, 2),
#   (488, 17),
#   (489, 4),
#   (490, 12),
#   (491, 1),
#   (492, 2),
#   (493, 1),
#   (494, 2),
#   (495, 2),
#   (496, 1),
#   (497, 54),
#   (498, 1),
#   (499, 3),
#   (500, 5),
#   (501, 3),
#   (502, 1),
#   (503, 2),
#   (504, 8),
#   (505, 1),
#   (506, 2),
#   (507, 5),
#   (508, 3),
#   (509, 2),
#   (510, 1),
#   (511, 5),
#   (512, 8),
#   (513, 1),
#   (514, 3),
#   (515, 4),
#   (516, 1),
#   (517, 2),
#   (518, 9),
#   (519, 3),
#   (520, 18),
#   (521, 17),
#   (522, 1),
#   (523, 1),
#   (524, 7),
#   (525, 1),
#   (526, 3),
#   (527, 5),
#   (528, 5),
#   (529, 1),
#   (530, 1),
#   (531, 4),
#   (532, 4),
#   (533, 14),
#   (534, 1),
#   (535, 1),
#   (536, 31),
#   (537, 3),
#   (538, 2),
#   (539, 7),
#   (540, 1),
#   (541, 193),
#   (542, 7),
#   (543, 1),
#   (544, 1),
#   (545, 1),
#   (546, 3),
#   (547, 15),
#   (548, 4),
#   (549, 3),
#   (550, 6),
#   (551, 7),
#   (552, 3),
#   (553, 1),
#   (554, 3),
#   (555, 3),
#   (556, 2),
#   (557, 6),
#   (558, 1),
#   (559, 23),
#   (560, 25),
#   (561, 1),
#   (562, 1),
#   (563, 9),
#   (564, 7),
#   (565, 1),
#   (566, 2),
#   (567, 1),
#   (568, 3),
#   (569, 20),
#   (570, 12),
#   (571, 1),
#   (572, 1),
#   (573, 3),
#   (574, 3),
#   (575, 2),
#   (576, 2),
#   (577, 1),
#   (578, 1),
#   (579, 12),
#   (580, 2),
#   (581, 1),
#   (582, 5),
#   (583, 1),
#   (584, 1),
#   (585, 6),
#   (586, 107),
#   (587, 2),
#   (588, 1),
#   (589, 8),
#   (590, 9),
#   (591, 1),
#   (592, 1),
#   (593, 2),
#   (594, 1),
#   (595, 1),
#   (596, 56),
#   (597, 2),
#   (598, 1),
#   (599, 11),
#   (600, 1),
#   (601, 1),
#   (602, 3),
#   (603, 2),
#   (604, 1),
#   (605, 3),
#   (606, 14),
#   (607, 3),
#   (608, 1),
#   (609, 55),
#   (610, 10),
#   (611, 20),
#   (612, 2),
#   (613, 2),
#   (614, 2),
#   (615, 1),
#   (616, 5),
#   (617, 1),
#   (618, 9),
#   (619, 1),
#   (620, 3),
#   (621, 4),
#   (622, 1),
#   (623, 1),
#   (624, 110),
#   (625, 7),
#   (626, 3),
#   (627, 6),
#   (628, 20),
#   (629, 1),
#   (630, 75),
#   (631, 1),
#   (632, 1),
#   (633, 1),
#   (634, 3),
#   (635, 2),
#   (636, 5),
#   (637, 1),
#   (638, 2),
#   (639, 2),
#   (640, 6),
#   (641, 2),
#   (642, 3),
#   (643, 4),
#   (644, 1),
#   (645, 3),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 5),
#   (650, 71),
#   (651, 1),
#   (652, 1),
#   (653, 4),
#   (654, 3),
#   (655, 1),
#   (656, 3),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 3),
#   (661, 76),
#   (662, 1),
#   (663, 23),
#   (664, 1),
#   (665, 33),
#   (666, 1),
#   (667, 1),
#   (668, 3),
#   (669, 41),
#   (670, 1),
#   (671, 1),
#   (672, 20),
#   (673, 14),
#   (674, 7),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 16),
#   (680, 2),
#   (681, 1),
#   (682, 1),
#   (683, 1),
#   (684, 6),
#   (685, 3),
#   (686, 3),
#   (687, 7),
#   (688, 27),
#   (689, 101),
#   (690, 10),
#   (691, 1),
#   (692, 1),
#   (693, 11),
#   (694, 4),
#   (695, 1),
#   (696, 1),
#   (697, 25),
#   (698, 71),
#   (699, 1),
#   (700, 57),
#   (701, 44),
#   (702, 1),
#   (703, 24),
#   (704, 19),
#   (705, 4),
#   (706, 6),
#   (707, 12),
#   (708, 30),
#   (709, 4),
#   (710, 6),
#   (711, 1),
#   (712, 1),
#   (713, 2),
#   (714, 2),
#   (715, 11),
#   (716, 6),
#   (717, 5),
#   (718, 28),
#   (719, 1),
#   (720, 8),
#   (721, 6),
#   (722, 1),
#   (723, 1),
#   (724, 1),
#   (725, 1),
#   (726, 1),
#   (727, 1),
#   (728, 2),
#   (729, 3),
#   (730, 7),
#   (731, 1),
#   (732, 94),
#   (733, 2),
#   (734, 1),
#   (735, 1),
#   (736, 1),
#   (737, 9),
#   (738, 24),
#   (739, 1),
#   (740, 1),
#   (741, 2),
#   (742, 1),
#   (743, 10),
#   (744, 7),
#   (745, 229),
#   (746, 1),
#   (747, 30),
#   (748, 1),
#   (749, 18),
#   (750, 1),
#   (751, 1),
#   (752, 1),
#   (753, 65),
#   (754, 1),
#   (755, 13),
#   (756, 18),
#   (757, 2),
#   (758, 36),
#   (759, 1),
#   (760, 1),
#   (761, 1),
#   (762, 7),
#   (763, 1),
#   (764, 1),
#   (765, 20),
#   (766, 3),
#   (767, 4),
#   (768, 1),
#   (769, 1),
#   (770, 2),
#   (771, 28),
#   (772, 3),
#   (773, 1),
#   (774, 1),
#   (775, 1),
#   (776, 1),
#   (777, 1),
#   (778, 1),
#   (779, 30),
#   (780, 4),
#   (781, 1),
#   (782, 1),
#   (783, 1),
#   (784, 3),
#   (785, 1),
#   (786, 3),
#   (787, 1),
#   (788, 2),
#   (789, 3),
#   (790, 1),
#   (791, 2),
#   (792, 6),
#   (793, 3),
#   (794, 1),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 58),
#   (803, 1),
#   (804, 1),
#   (805, 1),
#   (806, 7),
#   (807, 76),
#   (808, 1),
#   (809, 14),
#   (810, 2),
#   (811, 1),
#   (812, 7),
#   (813, 38),
#   (814, 8),
#   (815, 1),
#   (816, 1),
#   (817, 1),
#   (818, 2),
#   (819, 379),
#   (820, 75),
#   (821, 34),
#   (822, 11),
#   (823, 1),
#   (824, 2),
#   (825, 21),
#   (826, 1),
#   (827, 2),
#   (828, 2),
#   (829, 2),
#   (830, 1),
#   (831, 6),
#   (832, 4),
#   (833, 1),
#   (834, 35),
#   (835, 1),
#   (836, 1),
#   (837, 3),
#   (838, 13),
#   (839, 14),
#   (840, 3),
#   (841, 38),
#   (842, 1),
#   (843, 1),
#   (844, 34),
#   (845, 2),
#   (846, 2),
#   (847, 18),
#   (848, 11),
#   (849, 13),
#   (850, 4),
#   (851, 1),
#   (852, 1),
#   (853, 3),
#   (854, 3),
#   (855, 1),
#   (856, 7),
#   (857, 11),
#   (858, 2),
#   (859, 1),
#   (860, 23),
#   (861, 26),
#   (862, 1),
#   (863, 1),
#   (864, 12),
#   (865, 2),
#   (866, 46),
#   (867, 2),
#   (868, 1),
#   (869, 3),
#   (870, 11),
#   (871, 2),
#   (872, 1),
#   (873, 1),
#   (874, 8),
#   (875, 20),
#   (876, 4),
#   (877, 2),
#   (878, 1),
#   (879, 1),
#   (880, 1),
#   (881, 15),
#   (882, 9),
#   (883, 6),
#   (884, 3),
#   (885, 1),
#   (886, 9),
#   (887, 1),
#   (888, 1),
#   (889, 30),
#   (890, 11),
#   (891, 2),
#   (892, 2),
#   (893, 2),
#   (894, 13),
#   (895, 1),
#   (896, 8),
#   (897, 4),
#   (898, 2),
#   (899, 1),
#   (900, 2),
#   (901, 6),
#   (902, 1),
#   (903, 1),
#   (904, 1),
#   (905, 2),
#   (906, 26),
#   (907, 1),
#   (908, 1),
#   (909, 1),
#   (910, 1),
#   (911, 18),
#   (912, 1),
#   (913, 1),
#   (914, 4),
#   (915, 1),
#   (916, 1),
#   (917, 2),
#   (918, 17),
#   (919, 3),
#   (920, 1),
#   (921, 12),
#   (922, 2),
#   (923, 7),
#   (924, 3),
#   (925, 1),
#   (926, 3),
#   (927, 2),
#   (928, 15),
#   (929, 7),
#   (930, 1),
#   (931, 1),
#   (932, 6),
#   (933, 2),
#   (934, 9),
#   (935, 2),
#   (936, 12),
#   (937, 2),
#   (938, 30),
#   (939, 1),
#   (940, 1),
#   (941, 1),
#   (942, 2),
#   (943, 1),
#   (944, 1),
#   (945, 7),
#   (946, 11),
#   (947, 1),
#   (948, 20),
#   (949, 17),
#   (950, 1),
#   (951, 28),
#   (952, 1),
#   (953, 4),
#   (954, 1),
#   (955, 82),
#   (956, 17),
#   (957, 4),
#   (958, 3),
#   (959, 26),
#   (960, 1),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 10),
#   (965, 3),
#   (966, 2),
#   (967, 6),
#   (968, 8),
#   (969, 2),
#   (970, 1),
#   (971, 8),
#   (972, 1),
#   (973, 1),
#   (974, 2),
#   (975, 11),
#   (976, 2),
#   (977, 2),
#   (978, 10),
#   (979, 3),
#   (980, 2),
#   (981, 3),
#   (982, 1),
#   (983, 1),
#   (984, 7),
#   (985, 1),
#   (986, 9),
#   (987, 6),
#   (988, 2),
#   (989, 51),
#   (990, 3),
#   (991, 2),
#   (992, 3),
#   (993, 3),
#   (994, 8),
#   (995, 6),
#   (996, 3),
#   (997, 1),
#   (998, 2),
#   (999, 2),
#   ...],
#  [(3, 1),
#   (4, 2),
#   (10, 2),
#   (14, 2),
#   (15, 1),
#   (18, 3),
#   (27, 1),
#   (30, 1),
#   (41, 1),
#   (45, 2),
#   (49, 2),
#   (56, 1),
#   (62, 1),
#   (74, 7),
#   (76, 2),
#   (84, 1),
#   (85, 2),
#   (129, 1),
#   (135, 1),
#   (140, 2),
#   (142, 1),
#   (143, 1),
#   (149, 1),
#   (161, 1),
#   (174, 4),
#   (178, 1),
#   (192, 8),
#   (193, 4),
#   (199, 3),
#   (200, 1),
#   (202, 1),
#   (207, 1),
#   (210, 1),
#   (213, 3),
#   (214, 2),
#   (222, 1),
#   (233, 2),
#   (234, 2),
#   (236, 1),
#   (243, 1),
#   (244, 6),
#   (245, 5),
#   (250, 1),
#   (256, 1),
#   (266, 1),
#   (268, 1),
#   (272, 1),
#   (277, 1),
#   (278, 1),
#   (285, 5),
#   (297, 1),
#   (299, 1),
#   (302, 4),
#   (313, 18),
#   (325, 1),
#   (326, 2),
#   (340, 1),
#   (341, 1),
#   (346, 1),
#   (365, 2),
#   (366, 5),
#   (368, 6),
#   (398, 3),
#   (401, 11),
#   (406, 1),
#   (407, 1),
#   (408, 2),
#   (411, 1),
#   (412, 12),
#   (415, 1),
#   (424, 1),
#   (427, 1),
#   (435, 1),
#   (440, 1),
#   (441, 1),
#   (445, 6),
#   (447, 1),
#   (455, 6),
#   (458, 13),
#   (464, 6),
#   (472, 4),
#   (476, 7),
#   (482, 1),
#   (483, 1),
#   (484, 1),
#   (487, 1),
#   (488, 3),
#   (490, 1),
#   (497, 2),
#   (500, 8),
#   (502, 5),
#   (504, 1),
#   (511, 4),
#   (512, 3),
#   (518, 1),
#   (520, 4),
#   (527, 23),
#   (531, 5),
#   (534, 1),
#   (541, 3),
#   (544, 2),
#   (545, 3),
#   (548, 1),
#   (550, 1),
#   (551, 8),
#   (552, 1),
#   (557, 1),
#   (560, 3),
#   (569, 4),
#   (573, 7),
#   (576, 4),
#   (582, 3),
#   (586, 12),
#   (590, 3),
#   (596, 1),
#   (602, 2),
#   (605, 1),
#   (607, 2),
#   (612, 1),
#   (616, 3),
#   (624, 19),
#   (634, 2),
#   (638, 4),
#   (645, 1),
#   (649, 1),
#   (650, 5),
#   (663, 3),
#   (665, 2),
#   (668, 3),
#   (669, 3),
#   (672, 7),
#   (673, 2),
#   (679, 1),
#   (684, 1),
#   (687, 1),
#   (695, 7),
#   (697, 5),
#   (704, 3),
#   (707, 4),
#   (715, 1),
#   (728, 1),
#   (732, 7),
#   (733, 1),
#   (734, 1),
#   (736, 1),
#   (744, 1),
#   (760, 1),
#   (778, 2),
#   (779, 3),
#   (786, 1),
#   (802, 6),
#   (814, 7),
#   (819, 72),
#   (820, 6),
#   (825, 8),
#   (827, 3),
#   (828, 1),
#   (831, 1),
#   (832, 1),
#   (834, 2),
#   (841, 1),
#   (844, 1),
#   (870, 1),
#   (873, 1),
#   (894, 2),
#   (896, 1),
#   (906, 1),
#   (911, 2),
#   (913, 1),
#   (919, 1),
#   (923, 1),
#   (925, 3),
#   (928, 2),
#   (949, 1),
#   (951, 3),
#   (955, 2),
#   (972, 1),
#   (974, 1),
#   (983, 3),
#   (984, 3),
#   (987, 1),
#   (989, 2),
#   (990, 1),
#   (992, 1),
#   (1029, 1),
#   (1045, 1),
#   (1048, 8),
#   (1052, 3),
#   (1054, 2),
#   (1055, 4),
#   (1059, 3),
#   (1062, 1),
#   (1070, 1),
#   (1071, 1),
#   (1090, 5),
#   (1093, 16),
#   (1097, 4),
#   (1102, 5),
#   (1103, 1),
#   (1108, 3),
#   (1111, 1),
#   (1114, 2),
#   (1115, 1),
#   (1116, 16),
#   (1125, 1),
#   (1127, 19),
#   (1129, 14),
#   (1136, 2),
#   (1138, 2),
#   (1140, 21),
#   (1145, 1),
#   (1156, 1),
#   (1166, 15),
#   (1170, 2),
#   (1173, 1),
#   (1174, 2),
#   (1187, 1),
#   (1194, 1),
#   (1197, 3),
#   (1204, 1),
#   (1212, 3),
#   (1213, 1),
#   (1234, 1),
#   (1242, 8),
#   (1256, 3),
#   (1276, 1),
#   (1281, 2),
#   (1294, 2),
#   (1303, 2),
#   (1304, 1),
#   (1324, 1),
#   (1345, 2),
#   (1346, 1),
#   (1351, 1),
#   (1359, 1),
#   (1360, 1),
#   (1373, 1),
#   (1375, 1),
#   (1383, 2),
#   (1392, 1),
#   (1399, 1),
#   (1407, 30),
#   (1415, 1),
#   (1419, 5),
#   (1426, 6),
#   (1427, 11),
#   (1428, 1),
#   (1429, 6),
#   (1442, 3),
#   (1446, 1),
#   (1449, 1),
#   (1461, 4),
#   (1467, 1),
#   (1474, 5),
#   (1475, 1),
#   (1482, 1),
#   (1484, 5),
#   (1485, 1),
#   (1488, 1),
#   (1495, 2),
#   (1498, 7),
#   (1502, 1),
#   (1503, 2),
#   (1511, 2),
#   (1518, 1),
#   (1520, 1),
#   (1521, 1),
#   (1524, 1),
#   (1541, 11),
#   (1548, 1),
#   (1558, 2),
#   (1564, 1),
#   (1572, 6),
#   (1578, 1),
#   (1586, 8),
#   (1587, 6),
#   (1604, 8),
#   (1611, 81),
#   (1622, 2),
#   (1624, 1),
#   (1649, 1),
#   (1653, 1),
#   (1655, 2),
#   (1689, 1),
#   (1695, 1),
#   (1706, 3),
#   (1716, 2),
#   (1720, 1),
#   (1737, 1),
#   (1754, 22),
#   (1759, 15),
#   (1760, 1),
#   (1766, 1),
#   (1768, 1),
#   (1769, 1),
#   (1772, 1),
#   (1773, 3),
#   (1775, 14),
#   (1776, 9),
#   (1779, 1),
#   (1786, 2),
#   (1787, 2),
#   (1788, 2),
#   (1790, 1),
#   (1797, 3),
#   (1802, 6),
#   (1803, 17),
#   (1814, 3),
#   (1822, 1),
#   (1826, 2),
#   (1827, 1),
#   (1828, 1),
#   (1836, 2),
#   (1850, 2),
#   (1852, 14),
#   (1855, 6),
#   (1859, 5),
#   (1864, 2),
#   (1865, 1),
#   (1868, 6),
#   (1872, 12),
#   (1874, 5),
#   (1876, 1),
#   (1878, 1),
#   (1883, 1),
#   (1886, 1),
#   (1887, 4),
#   (1894, 5),
#   (1896, 3),
#   (1902, 3),
#   (1905, 1),
#   (1906, 2),
#   (1913, 1),
#   (1915, 4),
#   (1921, 2),
#   (1922, 1),
#   (1938, 4),
#   (1946, 5),
#   (1950, 6),
#   (1951, 1),
#   (1956, 7),
#   (1961, 1),
#   (1964, 1),
#   (1966, 1),
#   (1970, 5),
#   (1973, 1),
#   (1976, 1),
#   (1981, 15),
#   (1985, 1),
#   (1991, 3),
#   (1997, 1),
#   (1998, 10),
#   (2005, 1),
#   (2020, 4),
#   (2026, 1),
#   (2033, 1),
#   (2037, 6),
#   (2038, 7),
#   (2041, 1),
#   (2042, 1),
#   (2047, 11),
#   (2049, 1),
#   (2059, 1),
#   (2063, 1),
#   (2071, 1),
#   (2076, 31),
#   (2077, 16),
#   (2083, 1),
#   (2084, 53),
#   (2086, 1),
#   (2090, 1),
#   (2092, 1),
#   (2096, 13),
#   (2098, 7),
#   (2113, 1),
#   (2127, 35),
#   (2134, 2),
#   (2144, 2),
#   (2149, 3),
#   (2155, 4),
#   (2158, 1),
#   (2160, 2),
#   (2163, 18),
#   (2171, 1),
#   (2172, 34),
#   (2173, 1),
#   (2178, 11),
#   (2183, 1),
#   (2185, 3),
#   (2187, 3),
#   (2189, 1),
#   (2196, 1),
#   (2206, 1),
#   (2207, 2),
#   (2210, 2),
#   (2214, 1),
#   (2218, 11),
#   (2220, 1),
#   (2221, 5),
#   (2223, 1),
#   (2224, 10),
#   (2227, 21),
#   (2231, 1),
#   (2232, 1),
#   (2248, 11),
#   (2249, 1),
#   (2253, 2),
#   (2263, 6),
#   (2264, 5),
#   (2267, 2),
#   (2268, 2),
#   (2275, 2),
#   (2276, 5),
#   (2278, 1),
#   (2280, 13),
#   (2284, 5),
#   (4661, 13),
#   (4663, 56),
#   (4664, 1),
#   (4666, 1),
#   (4667, 20),
#   (4669, 49),
#   (4670, 1),
#   (4677, 5),
#   (4684, 11),
#   (4686, 3),
#   (4687, 2),
#   (4694, 4),
#   (4697, 4),
#   (4699, 2),
#   (4718, 2),
#   (4721, 1),
#   (4722, 1),
#   (4726, 4),
#   (4727, 2),
#   (4736, 3),
#   (4744, 10),
#   (4746, 9),
#   (4748, 2),
#   (4750, 6),
#   (4752, 10),
#   (4753, 1),
#   (4755, 1),
#   (4757, 1),
#   (4760, 2),
#   (4766, 3),
#   (4767, 1),
#   (4771, 10),
#   (4981, 1),
#   (4982, 4),
#   (4991, 2),
#   (4999, 1),
#   (5014, 1),
#   (5023, 4),
#   (5027, 1),
#   (5028, 1),
#   (5029, 1),
#   (5033, 1),
#   (5036, 1),
#   (5040, 1),
#   (5045, 1),
#   (5048, 2),
#   (5052, 3),
#   (5054, 4),
#   (5058, 1),
#   (5065, 3),
#   (5074, 2),
#   (5075, 4),
#   (5078, 5),
#   (5081, 4),
#   (5084, 17),
#   (5090, 1),
#   (5091, 3),
#   (5102, 1),
#   (5105, 11),
#   (5107, 44),
#   (5109, 1),
#   (5116, 6),
#   (5120, 4),
#   (5124, 1),
#   (5127, 1),
#   (5130, 4),
#   (5134, 14),
#   (5135, 2),
#   (5140, 34),
#   (5144, 1),
#   (5145, 1),
#   (5148, 1),
#   (5154, 3),
#   (5156, 1),
#   (5157, 2),
#   (5158, 1),
#   (5160, 3),
#   (5162, 2),
#   (5164, 17),
#   (5165, 14),
#   (5169, 16),
#   (5170, 1),
#   (5171, 3),
#   (5174, 11),
#   (5177, 16),
#   (5179, 4),
#   (5183, 7),
#   (5187, 2),
#   (5190, 4),
#   (5191, 17),
#   (5192, 5),
#   (5194, 1),
#   (5197, 2),
#   (5203, 3),
#   (5206, 1),
#   (5219, 3),
#   (5221, 1),
#   (5223, 2),
#   (5224, 1),
#   (5225, 57),
#   (5230, 4),
#   (5232, 2),
#   (5236, 1),
#   (5237, 3),
#   (5238, 1),
#   (5239, 1),
#   (5240, 1),
#   (5241, 2),
#   (5242, 1),
#   (5243, 1),
#   (5244, 1),
#   (5245, 5),
#   (5246, 1),
#   (5247, 2),
#   (5248, 1),
#   (5249, 1),
#   (5250, 1),
#   (5251, 2),
#   (5252, 1),
#   (5253, 1),
#   (5254, 1),
#   (5255, 2),
#   (5256, 2),
#   (5257, 1),
#   (5258, 2),
#   ...],
#  [(3, 1),
#   (10, 1),
#   (15, 1),
#   (18, 1),
#   (22, 2),
#   (27, 2),
#   (30, 2),
#   (31, 1),
#   (35, 3),
#   (45, 3),
#   (49, 2),
#   (55, 1),
#   (62, 1),
#   (67, 1),
#   (74, 13),
#   (76, 11),
#   (85, 1),
#   (95, 1),
#   (97, 3),
#   (103, 2),
#   (105, 1),
#   (107, 1),
#   (127, 1),
#   (129, 5),
#   (135, 3),
#   (138, 1),
#   (142, 1),
#   (143, 8),
#   (150, 1),
#   (152, 1),
#   (159, 2),
#   (174, 9),
#   (183, 3),
#   (185, 2),
#   (191, 1),
#   (192, 7),
#   (193, 10),
#   (194, 3),
#   (199, 4),
#   (207, 1),
#   (210, 2),
#   (213, 5),
#   (221, 1),
#   (222, 1),
#   (231, 1),
#   (233, 4),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (244, 9),
#   (245, 12),
#   (249, 1),
#   (256, 2),
#   (266, 2),
#   (272, 1),
#   (279, 1),
#   (282, 2),
#   (292, 2),
#   (296, 1),
#   (297, 3),
#   (302, 10),
#   (311, 1),
#   (313, 16),
#   (315, 2),
#   (325, 1),
#   (326, 2),
#   (331, 1),
#   (342, 2),
#   (343, 1),
#   (345, 4),
#   (346, 2),
#   (347, 1),
#   (350, 1),
#   (356, 1),
#   (366, 2),
#   (368, 6),
#   (385, 1),
#   (388, 2),
#   (390, 1),
#   (398, 2),
#   (401, 27),
#   (402, 2),
#   (406, 2),
#   (407, 2),
#   (408, 2),
#   (411, 1),
#   (412, 11),
#   (421, 1),
#   (426, 7),
#   (427, 2),
#   (432, 5),
#   (436, 2),
#   (437, 1),
#   (445, 4),
#   (446, 1),
#   (447, 4),
#   (452, 4),
#   (455, 3),
#   (458, 12),
#   (461, 1),
#   (464, 12),
#   (470, 1),
#   (472, 1),
#   (476, 2),
#   (482, 3),
#   (484, 1),
#   (487, 3),
#   (488, 1),
#   (489, 5),
#   (492, 1),
#   (497, 2),
#   (498, 1),
#   (500, 6),
#   (502, 3),
#   (504, 2),
#   (508, 3),
#   (511, 1),
#   (512, 4),
#   (520, 5),
#   (527, 12),
#   (531, 3),
#   (534, 2),
#   (536, 2),
#   (541, 20),
#   (544, 2),
#   (545, 4),
#   (547, 1),
#   (550, 4),
#   (551, 4),
#   (552, 2),
#   (555, 2),
#   (557, 3),
#   (560, 3),
#   (566, 1),
#   (568, 1),
#   (569, 4),
#   (573, 14),
#   (574, 1),
#   (575, 1),
#   (576, 2),
#   (586, 18),
#   (590, 2),
#   (596, 16),
#   (602, 3),
#   (605, 3),
#   (606, 3),
#   (607, 6),
#   (615, 2),
#   (616, 5),
#   (624, 23),
#   (638, 4),
#   (645, 1),
#   (654, 1),
#   (661, 6),
#   (663, 6),
#   (664, 1),
#   (665, 2),
#   (668, 6),
#   (669, 5),
#   (672, 14),
#   (673, 1),
#   (679, 2),
#   (684, 3),
#   (687, 1),
#   (695, 4),
#   (697, 3),
#   (698, 4),
#   (701, 2),
#   (704, 7),
#   (705, 2),
#   (706, 1),
#   (715, 1),
#   (732, 2),
#   (734, 1),
#   (737, 1),
#   (738, 4),
#   (741, 6),
#   (744, 3),
#   (753, 7),
#   (758, 1),
#   (779, 7),
#   (781, 1),
#   (784, 1),
#   (786, 2),
#   (791, 1),
#   (793, 4),
#   (802, 6),
#   (805, 2),
#   (809, 2),
#   (812, 2),
#   (814, 5),
#   (817, 1),
#   (818, 1),
#   (819, 135),
#   (820, 1),
#   (825, 11),
#   (827, 4),
#   (829, 1),
#   (831, 5),
#   (834, 8),
#   (841, 1),
#   (844, 2),
#   (853, 1),
#   (864, 2),
#   (869, 1),
#   (883, 5),
#   (884, 1),
#   (888, 1),
#   (894, 1),
#   (896, 1),
#   (907, 1),
#   (912, 5),
#   (914, 3),
#   (921, 3),
#   (925, 2),
#   (928, 1),
#   (944, 1),
#   (945, 8),
#   (949, 3),
#   (951, 4),
#   (955, 4),
#   (968, 1),
#   (978, 1),
#   (983, 1),
#   (984, 4),
#   (991, 2),
#   (994, 1),
#   (1029, 1),
#   (1036, 2),
#   (1043, 1),
#   (1044, 4),
#   (1045, 5),
#   (1046, 1),
#   (1048, 4),
#   (1050, 1),
#   (1054, 6),
#   (1055, 4),
#   (1056, 1),
#   (1071, 1),
#   (1072, 5),
#   (1084, 1),
#   (1093, 11),
#   (1097, 1),
#   (1101, 2),
#   (1102, 3),
#   (1108, 2),
#   (1114, 4),
#   (1115, 6),
#   (1116, 3),
#   (1125, 17),
#   (1127, 24),
#   (1129, 30),
#   (1134, 1),
#   (1136, 1),
#   (1139, 1),
#   (1140, 36),
#   (1144, 1),
#   (1145, 1),
#   (1161, 3),
#   (1166, 8),
#   (1172, 2),
#   (1173, 1),
#   (1174, 2),
#   (1175, 2),
#   (1181, 1),
#   (1189, 2),
#   (1191, 1),
#   (1194, 1),
#   (1197, 6),
#   (1204, 5),
#   (1210, 1),
#   (1212, 3),
#   (1213, 2),
#   (1215, 2),
#   (1242, 10),
#   (1243, 1),
#   (1246, 5),
#   (1256, 2),
#   (1262, 1),
#   (1263, 1),
#   (1264, 1),
#   (1276, 3),
#   (1277, 1),
#   (1281, 5),
#   (1282, 2),
#   (1284, 1),
#   (1285, 1),
#   (1294, 2),
#   (1296, 1),
#   (1302, 4),
#   (1303, 1),
#   (1304, 1),
#   (1306, 2),
#   (1307, 1),
#   (1316, 1),
#   (1326, 1),
#   (1334, 5),
#   (1339, 4),
#   (1351, 2),
#   (1357, 1),
#   (1359, 1),
#   (1373, 5),
#   (1384, 1),
#   (1390, 1),
#   (1395, 2),
#   (1407, 21),
#   (1423, 1),
#   (1426, 27),
#   (1427, 6),
#   (1429, 11),
#   (1438, 2),
#   (1441, 1),
#   (1442, 9),
#   (1446, 6),
#   (1448, 1),
#   (1455, 4),
#   (1457, 4),
#   (1461, 2),
#   (1464, 6),
#   (1469, 2),
#   (1474, 1),
#   (1475, 5),
#   (1481, 7),
#   (1484, 9),
#   (1486, 1),
#   (1489, 1),
#   (1495, 1),
#   (1498, 21),
#   (1499, 4),
#   (1500, 1),
#   (1502, 1),
#   (1503, 2),
#   (1511, 9),
#   (1518, 1),
#   (1521, 4),
#   (1524, 1),
#   (1525, 1),
#   (1541, 13),
#   (1548, 3),
#   (1553, 1),
#   (1559, 1),
#   (1564, 3),
#   (1572, 21),
#   (1578, 1),
#   (1579, 4),
#   (1586, 21),
#   (1587, 1),
#   (1601, 1),
#   (1604, 6),
#   (1605, 1),
#   (1611, 86),
#   (1617, 3),
#   (1622, 1),
#   (1625, 1),
#   (1639, 1),
#   (1643, 1),
#   (1644, 2),
#   (1646, 1),
#   (1648, 1),
#   (1649, 1),
#   (1655, 3),
#   (1656, 1),
#   (1660, 1),
#   (1677, 1),
#   (1678, 1),
#   (1683, 1),
#   (1684, 1),
#   (1686, 2),
#   (1687, 11),
#   (1689, 1),
#   (1690, 1),
#   (1694, 2),
#   (1698, 1),
#   (1703, 1),
#   (1708, 3),
#   (1739, 1),
#   (1741, 1),
#   (1754, 34),
#   (1759, 12),
#   (1773, 12),
#   (1775, 19),
#   (1776, 6),
#   (1778, 1),
#   (1779, 1),
#   (1782, 1),
#   (1786, 2),
#   (1788, 8),
#   (1795, 8),
#   (1797, 4),
#   (1800, 7),
#   (1802, 3),
#   (1803, 69),
#   (1808, 7),
#   (1814, 2),
#   (1820, 2),
#   (1826, 4),
#   (1828, 1),
#   (1836, 9),
#   (1838, 1),
#   (1840, 1),
#   (1843, 2),
#   (1850, 1),
#   (1852, 5),
#   (1854, 4),
#   (1855, 1),
#   (1859, 10),
#   (1861, 11),
#   (1864, 7),
#   (1865, 1),
#   (1868, 11),
#   (1872, 17),
#   (1874, 15),
#   (1878, 5),
#   (1879, 4),
#   (1880, 2),
#   (1883, 1),
#   (1886, 5),
#   (1887, 1),
#   (1894, 5),
#   (1896, 2),
#   (1902, 1),
#   (1904, 1),
#   (1905, 27),
#   (1906, 1),
#   (1907, 2),
#   (1911, 1),
#   (1912, 1),
#   (1913, 3),
#   (1921, 2),
#   (1922, 5),
#   (1932, 1),
#   (1938, 8),
#   (1941, 3),
#   (1943, 1),
#   (1946, 2),
#   (1950, 5),
#   (1956, 14),
#   (1957, 1),
#   (1958, 1),
#   (1966, 4),
#   (1970, 10),
#   (1972, 1),
#   (1973, 5),
#   (1976, 1),
#   (1981, 30),
#   (1984, 2),
#   (1985, 1),
#   (1990, 2),
#   (1991, 1),
#   (1992, 1),
#   (1993, 1),
#   (1998, 10),
#   (2001, 1),
#   (2011, 1),
#   (2013, 1),
#   (2015, 2),
#   (2020, 2),
#   (2021, 1),
#   (2022, 3),
#   (2031, 3),
#   (2037, 4),
#   (2038, 21),
#   (2041, 1),
#   (2042, 1),
#   (2046, 1),
#   (2047, 12),
#   (2049, 4),
#   (2058, 4),
#   (2063, 1),
#   (2067, 1),
#   (2074, 1),
#   (2076, 81),
#   (2077, 28),
#   (2081, 1),
#   (2084, 107),
#   (2086, 3),
#   (2096, 14),
#   (2098, 6),
#   (2107, 1),
#   (2113, 1),
#   (2127, 19),
#   (2134, 3),
#   (2142, 1),
#   (2144, 9),
#   (2149, 8),
#   (2153, 5),
#   (2155, 2),
#   (2160, 3),
#   (2161, 5),
#   (2163, 25),
#   (2165, 1),
#   (2171, 1),
#   (2172, 27),
#   (2178, 4),
#   (2181, 1),
#   (2183, 2),
#   (2185, 2),
#   (2187, 3),
#   (2189, 1),
#   (2191, 1),
#   (2196, 1),
#   (2199, 2),
#   (2200, 1),
#   (2202, 1),
#   (2206, 2),
#   (2207, 1),
#   (2210, 1),
#   (2215, 1),
#   (4170, 1),
#   (4171, 1),
#   (4174, 20),
#   (4179, 1),
#   (4192, 5),
#   (4193, 1),
#   (4194, 4),
#   (4196, 2),
#   (4197, 5),
#   (4204, 1),
#   (4207, 1),
#   (4209, 5),
#   (4211, 2),
#   (4213, 8),
#   (4219, 5),
#   (4227, 2),
#   (4232, 15),
#   (4236, 9),
#   (4238, 2),
#   (4242, 65),
#   (4243, 8),
#   (4244, 13),
#   (4248, 1),
#   (4255, 3),
#   (4256, 1),
#   (4263, 4),
#   (4267, 1),
#   (4271, 2),
#   (4274, 2),
#   (4280, 1),
#   (4284, 1),
#   (4285, 6),
#   (4289, 2),
#   ...],
#  [(0, 1),
#   (4, 1),
#   (5, 1),
#   (6, 8),
#   (10, 1),
#   (11, 8),
#   (12, 23),
#   (13, 2),
#   (14, 1),
#   (15, 1),
#   (18, 3),
#   (19, 4),
#   (20, 5),
#   (22, 5),
#   (30, 6),
#   (31, 14),
#   (35, 9),
#   (36, 4),
#   (38, 1),
#   (45, 3),
#   (49, 5),
#   (50, 1),
#   (53, 1),
#   (55, 1),
#   (56, 1),
#   (58, 2),
#   (59, 2),
#   (62, 1),
#   (63, 3),
#   (72, 44),
#   (74, 12),
#   (76, 9),
#   (77, 1),
#   (78, 1),
#   (79, 6),
#   (80, 5),
#   (81, 2),
#   (84, 21),
#   (85, 3),
#   (86, 4),
#   (87, 7),
#   (94, 1),
#   (95, 2),
#   (98, 5),
#   (103, 3),
#   (104, 1),
#   (107, 1),
#   (108, 14),
#   (109, 1),
#   (110, 8),
#   (112, 5),
#   (116, 1),
#   (120, 1),
#   (124, 5),
#   (126, 4),
#   (127, 3),
#   (129, 4),
#   (130, 2),
#   (136, 1),
#   (138, 1),
#   (140, 23),
#   (141, 4),
#   (142, 18),
#   (143, 11),
#   (149, 1),
#   (150, 9),
#   (151, 5),
#   (152, 9),
#   (159, 7),
#   (160, 3),
#   (161, 2),
#   (165, 36),
#   (167, 1),
#   (171, 4),
#   (172, 1),
#   (178, 2),
#   (179, 14),
#   (183, 12),
#   (192, 94),
#   (193, 22),
#   (194, 48),
#   (197, 1),
#   (199, 28),
#   (200, 55),
#   (201, 2),
#   (202, 8),
#   (203, 3),
#   (206, 3),
#   (207, 4),
#   (208, 51),
#   (210, 2),
#   (218, 5),
#   (222, 29),
#   (224, 3),
#   (225, 3),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (231, 6),
#   (233, 14),
#   (234, 7),
#   (235, 15),
#   (236, 12),
#   (237, 2),
#   (239, 3),
#   (241, 2),
#   (242, 7),
#   (243, 1),
#   (244, 51),
#   (245, 88),
#   (246, 3),
#   (248, 1),
#   (249, 1),
#   (251, 3),
#   (252, 2),
#   (253, 1),
#   (254, 41),
#   (255, 2),
#   (256, 2),
#   (257, 2),
#   (260, 3),
#   (262, 1),
#   (263, 1),
#   (264, 6),
#   (265, 12),
#   (266, 19),
#   (272, 2),
#   (276, 1),
#   (277, 4),
#   (278, 1),
#   (280, 1),
#   (285, 5),
#   (287, 2),
#   (289, 2),
#   (291, 1),
#   (293, 2),
#   (295, 1),
#   (296, 3),
#   (297, 10),
#   (300, 4),
#   (302, 26),
#   (304, 5),
#   (305, 4),
#   (306, 5),
#   (309, 3),
#   (310, 3),
#   (311, 2),
#   (313, 4),
#   (314, 1),
#   (315, 2),
#   (318, 2),
#   (319, 4),
#   (324, 1),
#   (325, 1),
#   (326, 117),
#   (327, 1),
#   (329, 1),
#   (332, 2),
#   (334, 2),
#   (335, 1),
#   (336, 1),
#   (337, 5),
#   (338, 2),
#   (339, 1),
#   (340, 4),
#   (341, 3),
#   (342, 1),
#   (343, 1),
#   (344, 1),
#   (345, 3),
#   (346, 3),
#   (347, 1),
#   (350, 1),
#   (351, 2),
#   (352, 1),
#   (353, 1),
#   (354, 7),
#   (355, 1),
#   (357, 10),
#   (359, 3),
#   (362, 5),
#   (365, 7),
#   (366, 3),
#   (368, 2),
#   (369, 4),
#   (373, 10),
#   (375, 1),
#   (383, 1),
#   (385, 3),
#   (388, 4),
#   (390, 13),
#   (391, 1),
#   (392, 1),
#   (393, 4),
#   (395, 3),
#   (398, 6),
#   (399, 3),
#   (400, 3),
#   (401, 59),
#   (402, 2),
#   (403, 1),
#   (407, 4),
#   (408, 99),
#   (410, 4),
#   (411, 8),
#   (412, 25),
#   (413, 2),
#   (418, 6),
#   (419, 30),
#   (423, 4),
#   (425, 5),
#   (426, 6),
#   (427, 5),
#   (432, 5),
#   (435, 1),
#   (436, 3),
#   (437, 1),
#   (441, 1),
#   (443, 3),
#   (444, 6),
#   (445, 13),
#   (446, 1),
#   (447, 4),
#   (450, 17),
#   (452, 3),
#   (455, 18),
#   (458, 7),
#   (459, 1),
#   (461, 5),
#   (464, 92),
#   (465, 2),
#   (466, 1),
#   (467, 2),
#   (470, 60),
#   (472, 1),
#   (473, 1),
#   (474, 2),
#   (475, 54),
#   (476, 1),
#   (478, 19),
#   (481, 1),
#   (482, 5),
#   (483, 4),
#   (484, 2),
#   (485, 2),
#   (486, 2),
#   (487, 7),
#   (488, 3),
#   (490, 2),
#   (493, 5),
#   (494, 3),
#   (497, 27),
#   (500, 1),
#   (502, 12),
#   (504, 1),
#   (505, 1),
#   (506, 2),
#   (507, 9),
#   (508, 7),
#   (509, 5),
#   (511, 50),
#   (515, 4),
#   (516, 4),
#   (518, 5),
#   (521, 2),
#   (525, 6),
#   (526, 1),
#   (527, 16),
#   (528, 1),
#   (529, 3),
#   (531, 15),
#   (532, 41),
#   (533, 2),
#   (539, 2),
#   (541, 19),
#   (542, 1),
#   (543, 1),
#   (545, 2),
#   (546, 1),
#   (547, 8),
#   (548, 9),
#   (549, 1),
#   (550, 5),
#   (551, 1),
#   (554, 8),
#   (555, 6),
#   (557, 11),
#   (558, 1),
#   (559, 1),
#   (560, 15),
#   (564, 11),
#   (566, 5),
#   (568, 4),
#   (569, 70),
#   (570, 3),
#   (572, 3),
#   (573, 6),
#   (574, 1),
#   (575, 3),
#   (576, 3),
#   (578, 1),
#   (580, 1),
#   (581, 3),
#   (582, 17),
#   (584, 1),
#   (585, 5),
#   (586, 18),
#   (590, 11),
#   (596, 2),
#   (598, 23),
#   (599, 1),
#   (601, 2),
#   (602, 9),
#   (603, 8),
#   (604, 1),
#   (605, 18),
#   (606, 19),
#   (607, 6),
#   (609, 19),
#   (610, 2),
#   (611, 4),
#   (612, 2),
#   (614, 1),
#   (615, 8),
#   (616, 3),
#   (621, 4),
#   (623, 4),
#   (624, 52),
#   (625, 2),
#   (626, 13),
#   (628, 8),
#   (631, 29),
#   (637, 2),
#   (638, 10),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 1),
#   (648, 39),
#   (649, 1),
#   (650, 11),
#   (652, 1),
#   (653, 3),
#   (654, 4),
#   (656, 5),
#   (658, 2),
#   (659, 1),
#   (663, 10),
#   (665, 44),
#   (668, 3),
#   (669, 40),
#   (670, 1),
#   (672, 10),
#   (673, 1),
#   (675, 1),
#   (679, 3),
#   (680, 2),
#   (681, 2),
#   (685, 9),
#   (688, 30),
#   (689, 26),
#   (690, 4),
#   (692, 5),
#   (693, 8),
#   (695, 5),
#   (697, 7),
#   (698, 11),
#   (699, 3),
#   (700, 1),
#   (701, 5),
#   (702, 4),
#   (704, 2),
#   (706, 1),
#   (712, 1),
#   (714, 2),
#   (715, 4),
#   (716, 4),
#   (718, 5),
#   (720, 1),
#   (721, 2),
#   (729, 9),
#   (730, 4),
#   (732, 27),
#   (733, 3),
#   (736, 1),
#   (737, 2),
#   (738, 9),
#   (741, 9),
#   (744, 50),
#   (749, 5),
#   (753, 3),
#   (754, 10),
#   (755, 2),
#   (756, 3),
#   (757, 2),
#   (758, 3),
#   (760, 2),
#   (762, 3),
#   (764, 7),
#   (765, 23),
#   (766, 4),
#   (767, 5),
#   (770, 4),
#   (771, 2),
#   (776, 2),
#   (777, 1),
#   (779, 22),
#   (780, 2),
#   (784, 9),
#   (785, 1),
#   (786, 32),
#   (789, 7),
#   (790, 1),
#   (791, 1),
#   (793, 2),
#   (796, 5),
#   (798, 1),
#   (802, 19),
#   (806, 1),
#   (809, 3),
#   (814, 21),
#   (815, 2),
#   (816, 2),
#   (817, 3),
#   (819, 217),
#   (820, 4),
#   (821, 5),
#   (822, 1),
#   (825, 2),
#   (829, 1),
#   (832, 2),
#   (834, 24),
#   (836, 4),
#   (837, 1),
#   (838, 1),
#   (839, 1),
#   (841, 25),
#   (844, 5),
#   (846, 3),
#   (847, 6),
#   (848, 2),
#   (850, 1),
#   (856, 3),
#   (857, 2),
#   (860, 20),
#   (861, 2),
#   (865, 1),
#   (866, 1),
#   (870, 4),
#   (871, 1),
#   (873, 1),
#   (874, 3),
#   (875, 2),
#   (877, 2),
#   (881, 3),
#   (887, 2),
#   (888, 2),
#   (889, 2),
#   (890, 6),
#   (896, 3),
#   (898, 2),
#   (899, 2),
#   (901, 5),
#   (906, 1),
#   (911, 7),
#   (918, 1),
#   (921, 2),
#   (923, 2),
#   (924, 1),
#   (925, 6),
#   (926, 7),
#   (927, 1),
#   (928, 4),
#   (929, 1),
#   (934, 2),
#   (936, 4),
#   (938, 2),
#   (942, 6),
#   (943, 1),
#   (945, 1),
#   (946, 2),
#   (949, 2),
#   (951, 5),
#   (955, 5),
#   (956, 8),
#   (957, 1),
#   (959, 3),
#   (961, 4),
#   (963, 1),
#   (964, 1),
#   (967, 1),
#   (968, 3),
#   (969, 1),
#   (971, 1),
#   (978, 7),
#   (981, 2),
#   (982, 2),
#   (984, 2),
#   (985, 2),
#   (986, 1),
#   (987, 2),
#   (989, 33),
#   (990, 6),
#   (991, 5),
#   (993, 7),
#   (995, 2),
#   (996, 1),
#   (997, 2),
#   (1007, 4),
#   (1009, 3),
#   (1012, 3),
#   (1013, 1),
#   (1016, 3),
#   (1017, 7),
#   (1018, 1),
#   (1019, 4),
#   (1020, 3),
#   (1022, 1),
#   (1023, 12),
#   (1027, 1),
#   (1028, 2),
#   (1029, 19),
#   (1030, 1),
#   (1033, 1),
#   (1036, 3),
#   (1037, 8),
#   (1038, 1),
#   (1039, 2),
#   (1040, 2),
#   (1044, 14),
#   (1045, 1),
#   (1046, 4),
#   (1048, 18),
#   (1049, 7),
#   (1050, 1),
#   (1052, 6),
#   (1054, 34),
#   (1055, 10),
#   (1057, 1),
#   (1060, 9),
#   (1070, 8),
#   (1071, 1),
#   (1072, 6),
#   (1074, 1),
#   (1077, 5),
#   (1078, 3),
#   (1081, 1),
#   (1083, 56),
#   (1084, 6),
#   (1088, 8),
#   (1090, 5),
#   (1091, 8),
#   (1092, 6),
#   (1093, 106),
#   (1095, 1),
#   (1097, 2),
#   (1098, 14),
#   (1099, 6),
#   (1100, 8),
#   (1102, 6),
#   (1103, 3),
#   (1105, 10),
#   (1107, 3),
#   (1108, 19),
#   (1109, 2),
#   (1111, 2),
#   (1114, 4),
#   (1115, 6),
#   (1116, 10),
#   (1117, 1),
#   (1119, 30),
#   (1122, 1),
#   (1123, 1),
#   (1124, 7),
#   (1125, 9),
#   (1127, 40),
#   (1129, 17),
#   (1134, 8),
#   (1136, 9),
#   (1140, 10),
#   (1150, 3),
#   (1151, 3),
#   (1152, 1),
#   (1153, 7),
#   (1154, 2),
#   (1155, 1),
#   (1156, 2),
#   (1157, 2),
#   (1158, 1),
#   (1159, 2),
#   (1161, 1),
#   (1162, 1),
#   (1163, 2),
#   (1170, 10),
#   (1171, 3),
#   (1172, 10),
#   (1173, 4),
#   (1175, 6),
#   (1177, 1),
#   (1178, 1),
#   (1183, 7),
#   (1187, 1),
#   (1189, 2),
#   (1191, 1),
#   (1192, 3),
#   (1193, 2),
#   (1194, 1),
#   (1195, 1),
#   (1197, 2),
#   (1202, 2),
#   (1203, 2),
#   (1204, 3),
#   (1212, 16),
#   (1215, 1),
#   (1222, 1),
#   (1225, 1),
#   (1229, 2),
#   (1230, 17),
#   (1231, 4),
#   (1234, 4),
#   (1235, 1),
#   (1238, 3),
#   (1242, 7),
#   (1244, 1),
#   (1246, 5),
#   (1247, 5),
#   (1248, 2),
#   (1256, 12),
#   (1258, 1),
#   (1259, 2),
#   (1261, 2),
#   (1262, 2),
#   (1267, 5),
#   (1270, 27),
#   (1272, 1),
#   (1273, 1),
#   (1274, 2),
#   (1277, 1),
#   (1279, 1),
#   (1281, 36),
#   (1283, 4),
#   (1284, 17),
#   (1285, 12),
#   (1286, 1),
#   (1287, 5),
#   (1289, 7),
#   (1293, 1),
#   (1294, 2),
#   (1297, 1),
#   (1298, 1),
#   (1300, 3),
#   (1302, 1),
#   (1303, 13),
#   (1304, 3),
#   (1307, 8),
#   (1313, 7),
#   (1320, 2),
#   (1325, 5),
#   (1326, 2),
#   (1335, 13),
#   (1336, 3),
#   (1341, 3),
#   (1342, 3),
#   (1343, 1),
#   (1344, 1),
#   (1345, 1),
#   (1347, 2),
#   (1357, 5),
#   (1358, 1),
#   (1359, 1),
#   (1360, 1),
#   (1367, 2),
#   (1375, 4),
#   (1381, 2),
#   (1383, 12),
#   (1384, 10),
#   (1385, 1),
#   (1387, 2),
#   (1388, 5),
#   (1389, 2),
#   (1390, 2),
#   (1391, 5),
#   (1392, 1),
#   (1396, 1),
#   (1397, 2),
#   (1399, 7),
#   (1402, 1),
#   (1404, 16),
#   (1405, 1),
#   (1407, 25),
#   (1413, 1),
#   (1415, 3),
#   (1416, 1),
#   (1419, 2),
#   (1420, 1),
#   (1423, 1),
#   (1424, 54),
#   (1427, 4),
#   (1429, 23),
#   (1431, 6),
#   (1432, 7),
#   (1436, 2),
#   (1437, 1),
#   (1438, 2),
#   (1439, 1),
#   (1441, 1),
#   (1442, 24),
#   (1446, 1),
#   (1447, 11),
#   (1449, 24),
#   (1452, 8),
#   (1455, 3),
#   (1457, 9),
#   (1458, 1),
#   (1459, 25),
#   (1461, 25),
#   (1464, 6),
#   (1467, 4),
#   (1468, 2),
#   (1469, 4),
#   (1470, 1),
#   (1474, 4),
#   (1475, 6),
#   (1480, 1),
#   (1481, 3),
#   (1482, 1),
#   (1484, 4),
#   (1485, 1),
#   (1489, 6),
#   (1490, 2),
#   (1491, 4),
#   (1492, 9),
#   (1493, 8),
#   (1494, 1),
#   (1496, 1),
#   (1497, 1),
#   (1498, 49),
#   (1499, 2),
#   (1500, 16),
#   (1502, 14),
#   (1503, 8),
#   (1505, 12),
#   (1507, 1),
#   (1508, 3),
#   (1510, 1),
#   (1511, 8),
#   (1515, 5),
#   (1517, 1),
#   (1518, 2),
#   (1521, 27),
#   (1523, 14),
#   (1524, 1),
#   (1526, 3),
#   (1531, 4),
#   (1532, 1),
#   (1535, 1),
#   (1539, 2),
#   (1541, 26),
#   (1542, 3),
#   (1545, 3),
#   (1546, 4),
#   (1548, 2),
#   (1552, 9),
#   (1553, 4),
#   (1554, 1),
#   (1555, 2),
#   (1557, 1),
#   (1558, 19),
#   (1560, 1),
#   (1561, 1),
#   (1563, 1),
#   (1564, 1),
#   (1565, 3),
#   (1567, 1),
#   (1572, 58),
#   (1575, 1),
#   (1578, 1),
#   (1579, 23),
#   (1580, 2),
#   (1581, 12),
#   (1582, 9),
#   (1881, 1),
#   (1886, 5),
#   (1887, 2),
#   (1888, 20),
#   (1891, 4),
#   (1893, 9),
#   (1894, 1),
#   (1895, 2),
#   (1896, 10),
#   (1897, 1),
#   (1900, 2),
#   (1901, 4),
#   (1902, 39),
#   (1904, 1),
#   (1905, 40),
#   (1906, 5),
#   (1907, 4),
#   (1911, 2),
#   (1912, 18),
#   (1913, 2),
#   (1915, 51),
#   (1918, 1),
#   (1921, 3),
#   (1922, 15),
#   (1931, 11),
#   (1938, 17),
#   (1940, 5),
#   (1941, 1),
#   (1943, 19),
#   (1944, 1),
#   (1946, 1),
#   (1947, 1),
#   (1950, 3),
#   (1952, 2),
#   (1955, 4),
#   (1957, 1),
#   (1958, 30),
#   (1961, 9),
#   (1962, 13),
#   (1964, 5),
#   (1965, 1),
#   (1966, 3),
#   (1970, 24),
#   (1971, 1),
#   (1972, 3),
#   (1973, 21),
#   (1975, 2),
#   (1976, 6),
#   (1980, 1),
#   (1981, 29),
#   (1982, 1),
#   (1983, 3),
#   (1984, 2),
#   (1985, 1),
#   (1986, 1),
#   (1987, 6),
#   (1988, 3),
#   (1989, 2),
#   (1991, 24),
#   (1993, 5),
#   (1994, 4),
#   (1995, 3),
#   (1998, 36),
#   (1999, 5),
#   (2001, 2),
#   (2003, 1),
#   ...]]

# %%
# creation of bigrams and trigrams
bigram = gensim.models.Phrases(documents)
trigram= gensim.models.Phrases(bigram[documents])

# %%
# add the created bigrams and trigrams to our documents
documents = [bigram[line] for line in documents]
documents = [trigram[line] for line in documents]
documents
# Out:
# [['emma',
#   'jane',
#   'austen',
#   'volume',
#   'chapter',
#   'emma',
#   'woodhouse',
#   'handsome',
#   'clever',
#   'rich',
#   'comfortable',
#   'home',
#   'happy',
#   'disposition',
#   'seem',
#   'unite',
#   'good',
#   'blessing',
#   'existence',
#   'live',
#   'nearly',
#   'year',
#   'world',
#   'little',
#   'distress',
#   'vex',
#   'young',
#   'two',
#   'daughter',
#   'affectionate',
#   'indulgent',
#   'father',
#   'consequence',
#   'sister',
#   'marriage',
#   'mistress',
#   'house',
#   'early',
#   'period',
#   'mother',
#   'die',
#   'long',
#   'ago',
#   'indistinct',
#   'remembrance',
#   'caress',
#   'place',
#   'supply',
#   'excellent',
#   'woman',
#   'governess',
#   'fall',
#   'little',
#   'short',
#   'mother',
#   'affection',
#   'sixteen',
#   'year',
#   'miss_taylor',
#   'woodhouse',
#   'family',
#   'less',
#   'governess',
#   'friend',
#   'fond',
#   'daughter',
#   'particularly',
#   'emma',
#   'intimacy',
#   'sister',
#   'even',
#   'miss_taylor',
#   'cease',
#   'hold',
#   'nominal',
#   'office',
#   'governess',
#   'mildness',
#   'temper',
#   'hardly',
#   'allow',
#   'impose',
#   'restraint',
#   'shadow',
#   'authority',
#   'long',
#   'pass',
#   'away',
#   'live',
#   'together',
#   'friend',
#   'friend',
#   'mutually',
#   'attach',
#   'emma',
#   'like',
#   'highly',
#   'esteem',
#   'miss_taylor',
#   'judgment',
#   'direct',
#   'chiefly',
#   'real',
#   'evil',
#   'indeed',
#   'emma',
#   'situation',
#   'power',
#   'rather',
#   'much',
#   'way',
#   'disposition',
#   'think',
#   'little',
#   'well',
#   'disadvantage',
#   'threaten',
#   'alloy',
#   'many',
#   'enjoyment',
#   'danger',
#   'however',
#   'present',
#   'unperceived',
#   'mean',
#   'rank',
#   'misfortune',
#   'sorrow',
#   'come',
#   'gentle',
#   'sorrow',
#   'shape',
#   'disagreeable',
#   'miss_taylor',
#   'marry',
#   'miss_taylor',
#   'loss',
#   'first',
#   'bring',
#   'grief',
#   'beloved',
#   'friend',
#   'emma',
#   'first',
#   'sit',
#   'mournful',
#   'think',
#   'continuance',
#   'wedding',
#   'go',
#   'father',
#   'leave',
#   'dine',
#   'together',
#   'prospect',
#   'third',
#   'cheer',
#   'long',
#   'evening',
#   'father',
#   'compose',
#   'sleep',
#   'dinner',
#   'usual',
#   'sit',
#   'think',
#   'lose',
#   'event',
#   'every',
#   'promise',
#   'happiness',
#   'friend',
#   'weston',
#   'man',
#   'unexceptionable',
#   'character',
#   'easy',
#   'fortune',
#   'suitable',
#   'age',
#   'pleasant',
#   'manner',
#   'satisfaction',
#   'consider',
#   'generous',
#   'friendship',
#   'always',
#   'wish',
#   'promote',
#   'match',
#   'black',
#   'morning',
#   'work',
#   'want',
#   'miss_taylor',
#   'feel',
#   'every',
#   'hour',
#   'every_day',
#   'recall',
#   'past',
#   'kindness',
#   'kindness',
#   'affection',
#   'sixteen',
#   'year',
#   'teach',
#   'play',
#   'five',
#   'year_old',
#   'devoted',
#   'power',
#   'attach',
#   'amuse',
#   'health',
#   'nurse',
#   'various',
#   'illness',
#   'childhood',
#   'large',
#   'debt',
#   'gratitude',
#   'owe',
#   'intercourse',
#   'last',
#   'seven',
#   'year',
#   'equal',
#   'foot',
#   'perfect',
#   'unreserve',
#   'soon',
#   'follow',
#   'isabella',
#   'marriage',
#   'leave',
#   'yet',
#   'dearer',
#   'tenderer',
#   'recollection',
#   'friend',
#   'companion',
#   'possess',
#   'intelligent',
#   'useful',
#   'gentle',
#   'know',
#   'way',
#   'family',
#   'interested',
#   'concern',
#   'peculiarly',
#   'interested',
#   'every',
#   'pleasure',
#   'every',
#   'scheme',
#   'one',
#   'speak',
#   'every',
#   'thought',
#   'arise',
#   'affection',
#   'never',
#   'find',
#   'fault',
#   'bear',
#   'change',
#   'true',
#   'friend',
#   'go',
#   'half_mile',
#   'emma',
#   'aware',
#   'great',
#   'must',
#   'difference',
#   'weston',
#   'half_mile',
#   'miss_taylor',
#   'house',
#   'advantage',
#   'natural',
#   'domestic',
#   'great',
#   'danger',
#   'suffer',
#   'intellectual',
#   'solitude',
#   'dearly',
#   'love',
#   'father',
#   'companion',
#   'meet',
#   'conversation',
#   'rational',
#   'playful',
#   'evil',
#   'actual',
#   'disparity',
#   'age',
#   'woodhouse',
#   'marry',
#   'early',
#   'much',
#   'increase',
#   'constitution',
#   'habit',
#   'valetudinarian',
#   'life',
#   'without',
#   'activity',
#   'mind',
#   'body',
#   'much',
#   'old_man',
#   'way',
#   'year',
#   'though',
#   'everywhere',
#   'beloved',
#   'friendliness',
#   'heart',
#   'amiable',
#   'temper',
#   'talent',
#   'recommend',
#   'time',
#   'sister',
#   'though',
#   'comparatively',
#   'little',
#   'removed',
#   'matrimony',
#   'settle',
#   'london',
#   'sixteen',
#   'mile',
#   'much',
#   'beyond',
#   'daily',
#   'reach',
#   'many',
#   'long',
#   'october',
#   'november',
#   'evening',
#   'must',
#   'struggle',
#   'hartfield',
#   'christmas',
#   'bring',
#   'next',
#   'visit',
#   'isabella',
#   'husband',
#   'little',
#   'child',
#   'fill',
#   'house',
#   'give',
#   'pleasant',
#   'society',
#   'highbury',
#   'large',
#   'populous',
#   'village',
#   'almost',
#   'amount',
#   'town',
#   'hartfield',
#   'spite',
#   'separate',
#   'lawn',
#   'shrubbery',
#   'name',
#   'really',
#   'belong',
#   'afford',
#   'equal',
#   'woodhouse',
#   'first',
#   'consequence',
#   'look',
#   'many',
#   'acquaintance',
#   'place',
#   'father',
#   'universally',
#   'civil',
#   'one',
#   'among',
#   'accept',
#   'lieu',
#   'miss_taylor',
#   'even',
#   'half',
#   'day',
#   'melancholy',
#   'change',
#   'emma',
#   'sigh',
#   'wish',
#   'impossible',
#   'thing',
#   'till',
#   'father',
#   'awoke',
#   'make',
#   'necessary',
#   'cheerful',
#   'spirit',
#   'require',
#   'support',
#   'nervous',
#   'man',
#   'easily',
#   'depressed',
#   'fond',
#   'every_body',
#   'use',
#   'hate',
#   'part',
#   'hate',
#   'change',
#   'every',
#   'kind',
#   'matrimony',
#   'origin',
#   'change',
#   'always',
#   'disagreeable',
#   'mean',
#   'yet',
#   'reconcile',
#   'daughter',
#   'marry',
#   'ever',
#   'speak',
#   'compassion',
#   'though',
#   'entirely',
#   'match',
#   'affection',
#   'oblige',
#   'part',
#   'miss_taylor',
#   'habit',
#   'gentle',
#   'selfishness',
#   'never',
#   'able',
#   'suppose',
#   'people',
#   'feel',
#   'differently',
#   'much',
#   'disposed',
#   'think',
#   'miss_taylor',
#   'do',
#   'sad',
#   'thing',
#   'great_deal',
#   'happy',
#   'spend',
#   'rest',
#   'life',
#   'hartfield',
#   'emma',
#   'smile',
#   'chat',
#   'cheerfully',
#   'keep',
#   'thought',
#   'tea',
#   'come',
#   'impossible',
#   'exactly',
#   'dinner',
#   'poor_miss_taylor',
#   'wish',
#   'pity',
#   'weston',
#   'ever',
#   'think',
#   'agree',
#   'papa',
#   'know',
#   'weston',
#   'pleasant',
#   'excellent',
#   'man',
#   'thoroughly',
#   'deserve',
#   'good',
#   'wife',
#   'miss_taylor',
#   'live',
#   'we',
#   'ever',
#   'bear',
#   'odd',
#   'humour',
#   'might',
#   'house',
#   'house',
#   'advantage',
#   'house',
#   'three',
#   'time',
#   'never',
#   'odd',
#   'humour',
#   'dear',
#   'often',
#   'shall',
#   'going',
#   'see',
#   'come',
#   'see',
#   'we',
#   'shall',
#   'always',
#   'meet',
#   'must',
#   'begin',
#   'must',
#   'go',
#   'pay',
#   'wedding',
#   'visit',
#   'soon',
#   'dear',
#   'get',
#   'far',
#   'randall',
#   'distance',
#   'walk',
#   'half',
#   'far',
#   'papa',
#   'nobody',
#   'think',
#   'walking',
#   'must',
#   'go',
#   'carriage',
#   'sure',
#   'carriage',
#   'james',
#   'like',
#   'put',
#   'horse',
#   'little',
#   'way',
#   'poor',
#   'horse',
#   'pay_visit',
#   'put',
#   'weston',
#   'stable',
#   'papa',
#   'know',
#   'settle',
#   'already',
#   'talk',
#   'weston',
#   'last_night',
#   'james',
#   'may',
#   'sure',
#   'always',
#   'like',
#   'go',
#   'randall',
#   'daughter',
#   'housemaid',
#   'doubt',
#   'whether',
#   'ever',
#   'take',
#   'we',
#   'anywhere',
#   'else',
#   'papa',
#   'get',
#   'hannah',
#   'good',
#   'place',
#   'nobody',
#   'think',
#   'hannah',
#   'till',
#   'mention',
#   'james',
#   'oblige',
#   'glad',
#   'think',
#   'lucky',
#   'poor',
#   'james',
#   'think',
#   'slight',
#   'upon',
#   'account',
#   'sure',
#   'make',
#   'good',
#   'servant',
#   'civil',
#   'girl',
#   'great',
#   'opinion',
#   'whenever',
#   'see',
#   'always',
#   'curtsey',
#   'ask',
#   'pretty',
#   'manner',
#   'needlework',
#   'observe',
#   'always',
#   'turn',
#   'lock',
#   'door',
#   'right',
#   'way',
#   'never',
#   'bang',
#   'sure',
#   'excellent',
#   'servant',
#   'great',
#   'comfort',
#   'poor_miss_taylor',
#   'somebody',
#   'use',
#   'see',
#   'whenever',
#   'james',
#   'goes',
#   'see',
#   'daughter',
#   'know',
#   'hear',
#   'we',
#   'able',
#   'tell',
#   'emma',
#   'spare',
#   'exertion',
#   'maintain',
#   'happy',
#   'flow',
#   'idea',
#   'hope',
#   'help',
#   'backgammon',
#   'get',
#   'father',
#   'tolerably',
#   'evening',
#   'attack',
#   'regret',
#   'place',
#   'visitor',
#   'immediately',
#   'afterwards',
#   'walked',
#   'make',
#   'unnecessary',
#   'knightley',
#   'sensible',
#   'man',
#   'seven',
#   'old',
#   'intimate',
#   'friend',
#   'family',
#   'particularly',
#   'connect',
#   'eld',
#   'brother',
#   'isabella',
#   'husband',
#   'live',
#   'mile',
#   'highbury',
#   'frequent',
#   'visitor',
#   'always',
#   'welcome',
#   'time',
#   'welcome',
#   'usual',
#   'come',
#   'directly',
#   'mutual',
#   'connexion',
#   'london',
#   'return',
#   'late',
#   'dinner',
#   'day',
#   'absence',
#   'walk',
#   'hartfield',
#   'well',
#   'brunswick_square',
#   'happy',
#   'circumstance',
#   'animate',
#   'woodhouse',
#   'time',
#   'knightley',
#   'cheerful',
#   'manner',
#   'always',
#   'good',
#   'many',
#   'inquiry',
#   'poor_isabella',
#   'child',
#   'answer',
#   'satisfactorily',
#   'woodhouse',
#   'gratefully',
#   'observe',
#   'kind',
#   'knightley',
#   'come',
#   'late',
#   'hour',
#   'call',
#   'upon',
#   'we',
#   'afraid',
#   'must',
#   'shock',
#   'walk',
#   'sir',
#   'beautiful',
#   'moonlight',
#   'night',
#   'mild',
#   'must',
#   'draw',
#   'back',
#   'great',
#   'fire',
#   'must',
#   'find',
#   'damp',
#   'dirty',
#   'wish',
#   'may',
#   'catch_cold',
#   'dirty',
#   'sir',
#   'look',
#   'shoe',
#   'speck',
#   'well',
#   'quite',
#   'surprising',
#   'vast',
#   'deal',
#   'rain',
#   'rain',
#   'dreadfully',
#   'hard',
#   'half_hour',
#   'breakfast',
#   'want',
#   'put',
#   'wedding',
#   'bye',
#   'wish',
#   'joy',
#   'pretty',
#   'well',
#   'aware',
#   'sort',
#   'joy',
#   'must',
#   'feel',
#   'hurry',
#   'congratulation',
#   'hope',
#   'go',
#   'tolerably',
#   'well',
#   'behave',
#   'cry',
#   'ah',
#   'poor_miss_taylor',
#   'sad',
#   'business',
#   'poor_miss',
#   'woodhouse',
#   'please',
#   'possibly',
#   'poor_miss_taylor',
#   'great_regard',
#   'emma',
#   'come',
#   'question',
#   'dependence',
#   'independence',
#   'rate',
#   'must',
#   'better',
#   'one',
#   'please',
#   'two',
#   'especially',
#   'two',
#   'fanciful',
#   'troublesome',
#   'creature',
#   'emma',
#   'playfully',
#   'head',
#   'know',
#   'certainly',
#   'father',
#   'believe',
#   'true',
#   'dear',
#   'indeed',
#   'woodhouse',
#   'sigh',
#   'afraid',
#   'sometimes',
#   'fanciful',
#   'troublesome',
#   'dearest',
#   'papa',
#   'think',
#   'mean',
#   'suppose',
#   'knightley',
#   'mean',
#   'horrible',
#   'idea',
#   'oh',
#   'mean',
#   'knightley',
#   'loves',
#   'find',
#   'fault',
#   'know',
#   'joke',
#   'joke',
#   'always',
#   'like',
#   'one',
#   'another',
#   'knightley',
#   'fact',
#   'one',
#   'people',
#   'see',
#   'fault',
#   'emma',
#   'woodhouse',
#   'one',
#   'ever',
#   'tell',
#   'though',
#   'particularly',
#   'agreeable',
#   'emma',
#   'know',
#   'much_less',
#   'father',
#   'really',
#   'suspect',
#   'circumstance',
#   'think',
#   'perfect',
#   'every_body',
#   'emma',
#   'know',
#   'never',
#   'flat',
#   'knightley',
#   'mean',
#   'reflection',
#   'body',
#   'miss_taylor',
#   'use',
#   'two',
#   'person',
#   'please',
#   'one',
#   'chance',
#   'must',
#   'gainer',
#   'well',
#   'emma',
#   'willing',
#   'let',
#   'pass',
#   'want',
#   'hear',
#   'wedding',
#   'shall',
#   'happy',
#   'tell',
#   'behave',
#   'charmingly',
#   'every_body',
#   'punctual',
#   'every_body',
#   'good',
#   'look',
#   'tear',
#   'hardly',
#   'long',
#   'face',
#   'see',
#   'oh',
#   'felt',
#   'go',
#   'half_mile',
#   'apart',
#   'sure',
#   'meeting',
#   'every_day',
#   'dear_emma',
#   'bear',
#   'every_thing',
#   'well',
#   'father',
#   'knightley',
#   'really',
#   'sorry',
#   'lose',
#   'poor_miss_taylor',
#   'sure',
#   'miss',
#   'think',
#   'emma',
#   'turn_away',
#   'head',
#   'divide',
#   'tear',
#   'smile',
#   'impossible',
#   'emma',
#   'miss',
#   'companion',
#   'knightley',
#   'like',
#   'well',
#   'sir',
#   'suppose',
#   'know',
#   'much',
#   'marriage',
#   'miss_taylor',
#   'advantage',
#   'know',
#   'acceptable',
#   'must',
#   'miss_taylor',
#   'time',
#   'life',
#   'settle',
#   'home',
#   'important',
#   'secure',
#   'comfortable',
#   'provision',
#   'therefore',
#   'allow',
#   'feel',
#   'much',
#   'pain',
#   'pleasure',
#   'every',
#   'friend',
#   'miss_taylor',
#   'must',
#   'glad',
#   'happily',
#   'marry',
#   'forget',
#   'one',
#   'matter',
#   'joy',
#   'emma',
#   'considerable',
#   'one',
#   'make_match',
#   'make_match',
#   'know',
#   ...],
#  ['tragedie',
#   'macbeth',
#   'william',
#   'shakespeare',
#   'actus',
#   'primus',
#   'scoena',
#   'prima',
#   'thunder',
#   'lightning',
#   'enter',
#   'three',
#   'witch',
#   'shall',
#   'three',
#   'meet',
#   'againe',
#   'thunder',
#   'lightning',
#   'raine',
#   'do',
#   'battaile',
#   'lose',
#   'wonne',
#   'ere',
#   'set',
#   'sunne',
#   'place',
#   'vpon',
#   'heath',
#   'meet',
#   'macbeth',
#   'come',
#   'padock',
#   'call',
#   'anon',
#   'faire',
#   'foule',
#   'foule',
#   'faire',
#   'houer',
#   'fogge',
#   'filthie',
#   'ayre',
#   'exeunt_scena_secunda',
#   'alarum',
#   'within',
#   'enter_king',
#   'malcome',
#   'donalbaine',
#   'lenox',
#   'attendant',
#   'meet',
#   'bleed',
#   'captaine',
#   'king',
#   'bloody',
#   'man',
#   'report',
#   'seemeth',
#   'plight',
#   'reuolt',
#   'new',
#   'state',
#   'mal',
#   'serieant',
#   'like',
#   'good',
#   'hardie',
#   'souldier',
#   'fight',
#   'captiuitie',
#   'haile',
#   'braue',
#   'friend',
#   'king',
#   'knowledge',
#   'broyle',
#   'thou',
#   'didst',
#   'leaue',
#   'cap',
#   'doubtfull',
#   'stand',
#   'two',
#   'spend',
#   'swimmer',
#   'doe',
#   'cle',
#   'together',
#   'choake',
#   'art',
#   'mercilesse',
#   'macdonwald',
#   'worthie',
#   'rebell',
#   'multiplying',
#   'villanie',
#   'nature',
#   'doe',
#   'swarme',
#   'vpon',
#   'westerne',
#   'isle',
#   'kerne',
#   'gallowgrosse',
#   'supply',
#   'fortune',
#   'damn',
#   'quarry',
#   'smile',
#   'shew',
#   'like',
#   'rebell',
#   'whore',
#   'weake',
#   'braue',
#   'macbeth',
#   'well',
#   'hee',
#   'deserue',
#   'name',
#   'disdayne',
#   'fortune',
#   'brandisht',
#   'steele',
#   'smoak',
#   'bloody',
#   'execution',
#   'like',
#   'valour',
#   'minion',
#   'caru',
#   'passage',
#   'till',
#   'hee',
#   'fac',
#   'slaue',
#   'neu',
#   'r',
#   'shooke',
#   'hand',
#   'bad',
#   'farwell',
#   'till',
#   'vnseam',
#   'naue',
#   'toth',
#   'chop',
#   'fix',
#   'head',
#   'vpon',
#   'battlement',
#   'king',
#   'valiant',
#   'cousin',
#   'worthy',
#   'gentleman',
#   'cap',
#   'whence',
#   'sunne',
#   'reflection',
#   'shipwracking',
#   'storm',
#   'direfull',
#   'thunder',
#   'spring',
#   'whence',
#   'comfort',
#   'seem',
#   'come',
#   'discomfort',
#   'swell',
#   'marke',
#   'king',
#   'scotland',
#   'marke',
#   'soon',
#   'iustice',
#   'valour',
#   'arm',
#   'compell',
#   'skip',
#   'kerne',
#   'trust',
#   'heeles',
#   'norweyan',
#   'lord',
#   'surueye',
#   'vantage',
#   'furbusht',
#   'arm',
#   'new',
#   'supplye',
#   'man',
#   'begin',
#   'fresh',
#   'assault',
#   'king',
#   'dismay',
#   'captain',
#   'macbeth',
#   'banquoh',
#   'cap',
#   'yes',
#   'sparrowes',
#   'eagles',
#   'hare',
#   'lyon',
#   'sooth',
#   'must',
#   'report',
#   'cannon',
#   'double',
#   'crack',
#   'doubly',
#   'redouble',
#   'stroake',
#   'vpon',
#   'foe',
#   'except',
#   'mean',
#   'bathe',
#   'reek',
#   'wound',
#   'memorize',
#   'another',
#   'golgotha',
#   'tell',
#   'faint',
#   'gash',
#   'cry',
#   'helpe',
#   'king',
#   'well',
#   'thy',
#   'word',
#   'become',
#   'thee',
#   'thy',
#   'wound',
#   'smack',
#   'honor',
#   'goe',
#   'get',
#   'surgeon',
#   'enter',
#   'rosse',
#   'angus',
#   'come',
#   'mal',
#   'worthy',
#   'thane',
#   'rosse',
#   'lenox',
#   'haste',
#   'look',
#   'eye',
#   'looke',
#   'seem',
#   'speake',
#   'thing',
#   'strange',
#   'rosse',
#   'god',
#   'saue',
#   'king',
#   'king',
#   'whence',
#   'thou',
#   'worthy',
#   'thane',
#   'rosse',
#   'fiffe',
#   'great',
#   'king',
#   'norweyan',
#   'banners',
#   'flowt',
#   'skie',
#   'fanne',
#   'people',
#   'cold',
#   'norway',
#   'himselfe',
#   'terrible',
#   'number',
#   'assist',
#   'disloyall',
#   'traytor',
#   'thane_cawdor',
#   'begin',
#   'dismall',
#   'conflict',
#   'till',
#   'bellona',
#   'bridegroome',
#   'lapt',
#   'proofe',
#   'confront',
#   'point',
#   'point',
#   'rebellious',
#   'arme',
#   'arme',
#   'curb',
#   'lauish',
#   'spirit',
#   'conclude',
#   'victorie',
#   'fall',
#   'vs',
#   'king',
#   'great',
#   'happinesse',
#   'rosse',
#   'sweno',
#   'norwayes',
#   'king',
#   'craue',
#   'composition',
#   'deigne',
#   'buriall',
#   'man',
#   'till',
#   'disburse',
#   'saint',
#   'colme',
#   'ynch',
#   'ten_thousand',
#   'dollar',
#   'generall',
#   'vse',
#   'king',
#   'thane_cawdor',
#   'shall',
#   'deceiue',
#   'bosome',
#   'interest',
#   'goe',
#   'pronounce',
#   'present',
#   'death',
#   'former',
#   'title',
#   'greet',
#   'macbeth',
#   'rosse',
#   'ile',
#   'see',
#   'do',
#   'king',
#   'hath',
#   'lose',
#   'noble',
#   'macbeth',
#   'hath',
#   'wonne',
#   'exeunt_scena',
#   'tertia',
#   'thunder',
#   'enter',
#   'three',
#   'witch',
#   'hast',
#   'thou',
#   'beene',
#   'sister',
#   'kill',
#   'swine',
#   'sister',
#   'thou',
#   'saylors',
#   'wife',
#   'chestnut',
#   'lappe',
#   'mouncht',
#   'mouncht',
#   'mouncht',
#   'giue',
#   'quoth',
#   'aroynt',
#   'thee',
#   'witch',
#   'ronyon',
#   'cryes',
#   'husband',
#   'aleppo',
#   'go',
#   'master',
#   'tiger',
#   'syue',
#   'ile',
#   'thither',
#   'sayle',
#   'like',
#   'rat',
#   'without',
#   'tayle',
#   'ile',
#   'doe',
#   'ile',
#   'doe',
#   'ile',
#   'doe',
#   'ile',
#   'giue',
#   'thee',
#   'winde',
#   'kinde',
#   'another',
#   'selfe',
#   'haue',
#   'port',
#   'blow',
#   'quarter',
#   'know',
#   'card',
#   'ile',
#   'dreyne',
#   'drie',
#   'hay',
#   'sleepe',
#   'shall',
#   'neyther',
#   'night',
#   'day',
#   'hang',
#   'vpon',
#   'lid',
#   'shall',
#   'liue',
#   'man',
#   'forbid',
#   'wearie',
#   'nine',
#   'time',
#   'nine',
#   'shall',
#   'dwindle',
#   'peake',
#   'pine',
#   'though',
#   'barke',
#   'lose',
#   'yet',
#   'shall',
#   'looke',
#   'haue',
#   'shew',
#   'shew',
#   'haue',
#   'pilot',
#   'thumbe',
#   'wrackt',
#   'homeward',
#   'come',
#   'drum',
#   'within',
#   'drumme',
#   'drumme',
#   'macbeth',
#   'doth',
#   'come',
#   'weyward',
#   'sister',
#   'hand',
#   'hand',
#   'poster',
#   'sea',
#   'land',
#   'thus',
#   'doe',
#   'goe',
#   'thrice',
#   'thine',
#   'thrice',
#   'mine',
#   'thrice',
#   'againe',
#   'make',
#   'vp',
#   'nine',
#   'peace',
#   'charme',
#   'wound',
#   'vp',
#   'enter_macbeth',
#   'banquo',
#   'macb',
#   'foule',
#   'faire',
#   'day',
#   'haue_seene',
#   'banquo',
#   'farre',
#   'call',
#   'soris',
#   'wither',
#   'wilde',
#   'attyre',
#   'looke',
#   'like',
#   'th',
#   'inhabitant',
#   'earth',
#   'yet',
#   'liue',
#   'aught',
#   'man',
#   'may',
#   'question',
#   'seeme',
#   'vnderstand',
#   'choppie',
#   'finger',
#   'lay',
#   'vpon',
#   'skinnie',
#   'lip',
#   'woman',
#   'yet',
#   'beard',
#   'forbid',
#   'interprete',
#   'mac',
#   'speake',
#   'haile',
#   'macbeth',
#   'haile',
#   'thee',
#   'thane',
#   'glamis',
#   'haile',
#   'macbeth',
#   'haile',
#   'thee',
#   'thane_cawdor',
#   'haile',
#   'macbeth',
#   'shalt',
#   'king',
#   'hereafter',
#   'banq',
#   'good',
#   'sir',
#   'doe',
#   'start',
#   'seeme',
#   'feare',
#   'thing',
#   'doe',
#   'sound',
#   'faire',
#   'name',
#   'truth',
#   'ye',
#   'fantasticall',
#   'indeed',
#   'outwardly',
#   'ye',
#   'shew',
#   'noble',
#   'partner',
#   'greet',
#   'present',
#   'grace',
#   'great',
#   'prediction',
#   'noble',
#   'hauing',
#   'royall',
#   'hope',
#   'seem',
#   'wrapt',
#   'withall',
#   'speake',
#   'looke',
#   'seed',
#   'time',
#   'graine',
#   'grow',
#   'speake',
#   'neyther',
#   'begge',
#   'feare',
#   'fauor',
#   'hate',
#   'hayle',
#   'hayle',
#   'hayle',
#   'lesser',
#   'macbeth',
#   'greater',
#   'happy',
#   'yet',
#   'much',
#   'happyer',
#   'thou_shalt',
#   'get',
#   'king',
#   'though',
#   'thou',
#   'none',
#   'haile',
#   'macbeth',
#   'banquo',
#   'banquo',
#   'macbeth',
#   'haile',
#   'macb',
#   'stay',
#   'imperfect',
#   'speaker',
#   'tell',
#   'sinell',
#   'death',
#   'know',
#   'thane',
#   'glamis',
#   'cawdor',
#   'thane_cawdor',
#   'liue',
#   'prosperous',
#   'gentleman',
#   'king',
#   'stand',
#   'within',
#   'prospect',
#   'beleefe',
#   'cawdor',
#   'whence',
#   'owe',
#   'strange',
#   'intelligence',
#   'vpon',
#   'blast',
#   'heath',
#   'stop',
#   'way',
#   'prophetique',
#   'greeting',
#   'speake',
#   'charge',
#   'witch',
#   'vanish',
#   'banq',
#   'earth',
#   'hath',
#   'bubble',
#   'water',
#   'ha',
#   'whither',
#   'vanish',
#   'macb',
#   'ayre',
#   'seem',
#   'corporall',
#   'melt',
#   'breath',
#   'winde',
#   'banq',
#   'thing',
#   'doe',
#   'speake',
#   'haue',
#   'eat',
#   'insane',
#   'root',
#   'take',
#   'reason',
#   'prisoner',
#   'macb',
#   'child',
#   'shall',
#   'king',
#   'banq',
#   'shall',
#   'king',
#   'macb',
#   'thane_cawdor',
#   'go',
#   'banq',
#   'toth',
#   'tune',
#   'word',
#   'enter',
#   'rosse',
#   'angus',
#   'rosse',
#   'king',
#   'hath',
#   'happily',
#   'receiu',
#   'macbeth',
#   'newes',
#   'thy',
#   'successe',
#   'read',
#   'thy',
#   'personall',
#   'venture',
#   'rebel',
#   'sight',
#   'wonder',
#   'prayse',
#   'doe',
#   'contend',
#   'thine',
#   'silenc',
#   'view',
#   'rest',
#   'day',
#   'find',
#   'thee',
#   'stout',
#   'norweyan',
#   'rank',
#   'nothing',
#   'afeard',
#   'thy_selfe',
#   'didst',
#   'make',
#   'strange',
#   'image',
#   'death',
#   'thick',
#   'tale',
#   'post',
#   'post',
#   'euery',
#   'one',
#   'beare',
#   'thy',
#   'prayse',
#   'kingdome',
#   'great',
#   'defence',
#   'powr',
#   'downe',
#   'ang',
#   'wee',
#   'send',
#   'giue',
#   'thee',
#   'royall',
#   'master',
#   'thank',
#   'onely',
#   'harrold',
#   'thee',
#   'sight',
#   'pay',
#   'thee',
#   'rosse',
#   'earnest',
#   'great',
#   'honor',
#   'bad',
#   'call',
#   'thee',
#   'thane_cawdor',
#   'addition',
#   'haile',
#   'worthy',
#   'thane',
#   'thine',
#   'banq',
#   'deuill',
#   'speake',
#   'true',
#   'macb',
#   'thane_cawdor',
#   'liue',
#   'doe',
#   'dresse',
#   'borrow',
#   'robe',
#   'ang',
#   'thane',
#   'liue',
#   'yet',
#   'vnder',
#   'heauie',
#   'iudgement',
#   'beare',
#   'life',
#   'deserue',
#   'loose',
#   'whether',
#   'combin',
#   'norway',
#   'lyne',
#   'rebell',
#   'hide',
#   'helpe',
#   'vantage',
#   'countreye',
#   'wracke',
#   'know',
#   'treasons',
#   'capitall',
#   'confess',
#   'prou',
#   'haue',
#   'ouerthrowne',
#   'macb',
#   'glamys',
#   'thane_cawdor',
#   'great',
#   'behinde',
#   'thanke',
#   'paine',
#   'doe',
#   'hope',
#   'child',
#   'shall',
#   'king',
#   'gaue',
#   'thane_cawdor',
#   'promis',
#   'lesse',
#   'banq',
#   'trust',
#   'home',
#   'might',
#   'yet',
#   'enkindle',
#   'vnto',
#   'crowne',
#   'besides',
#   'thane_cawdor',
#   'strange',
#   'oftentimes',
#   'winne',
#   'vs',
#   'harme',
#   'instrument',
#   'darknesse',
#   'tell',
#   'vs',
#   'truth',
#   'winne',
#   'vs',
#   'honest',
#   'trifle',
#   'deep',
#   'consequence',
#   'cousin',
#   'word',
#   'pray',
#   'macb',
#   'two',
#   'truth',
#   'tell',
#   'happy',
#   'prologue',
#   'swell',
#   'act',
#   'imperiall',
#   'theame',
#   'thanke',
#   'gentleman',
#   'supernaturall',
#   'sollicite',
#   'ill',
#   'good',
#   'ill',
#   'hath',
#   'giuen',
#   'earnest',
#   'successe',
#   'commence',
#   'truth',
#   'thane_cawdor',
#   'good',
#   'doe',
#   'yeeld',
#   'suggestion',
#   'whose',
#   'horrid',
#   'image',
#   'doth',
#   'vnfixe',
#   'heire',
#   'make',
#   'seat',
#   'heart',
#   'knock',
#   'ribbe',
#   'vse',
#   'nature',
#   'present',
#   'feare',
#   'lesse',
#   'horrible',
#   'imagining',
#   'think',
#   'whose',
#   'murther',
#   'yet',
#   'fantasticall',
#   'shake',
#   'single',
#   'state',
#   'man',
#   'function',
#   'smother',
#   'surmise',
#   'nothing',
#   'banq',
#   'looke',
#   'partner',
#   'rapt',
#   'macb',
#   'chance',
#   'haue',
#   'king',
#   'chance',
#   'may',
#   'crowne',
#   'without',
#   'stirre',
#   'banq',
#   'new',
#   'honor',
#   'come',
#   'vpon',
#   'like',
#   'strange',
#   'garment',
#   'cleaue',
#   'mould',
#   'aid',
#   'vse',
#   'macb',
#   'come',
#   'come',
#   'may',
#   'time',
#   'houre',
#   'run',
#   'roughest',
#   'day',
#   'banq',
#   'worthy',
#   'macbeth',
#   'wee',
#   'stay',
#   'vpon',
#   'leysure',
#   'macb',
#   'giue',
#   'fauour',
#   'dull',
#   'braine',
#   'work',
#   'thing',
#   'forget',
#   'kinde',
#   'gentleman',
#   'paine',
#   'registre',
#   'euery',
#   'day',
#   'turne',
#   'leafe',
#   'reade',
#   'let_vs',
#   'toward',
#   'king',
#   'thinke',
#   'vpon',
#   'hath',
#   'chanc',
#   'time',
#   'interim',
#   'hauing',
#   'weigh',
#   'let_vs',
#   'speake',
#   'free',
#   'heart',
#   'banq',
#   'gladly',
#   'macb',
#   'till',
#   'enough',
#   'come',
#   'friend',
#   'exeunt_scena',
#   'quarta',
#   'flourish',
#   'enter_king',
#   'lenox',
#   'malcolme',
#   'donalbaine',
#   'attendant',
#   'king',
#   'execution',
#   ...],
#  ['tragedie',
#   'hamlet',
#   'william',
#   'shakespeare',
#   'actus',
#   'primus',
#   'scoena',
#   'prima',
#   'enter',
#   'barnardo',
#   'francisco',
#   'two',
#   'centinel',
#   'barnardo',
#   'fran',
#   'nay',
#   'answer',
#   'stand',
#   'vnfold',
#   'selfe',
#   'bar',
#   'long',
#   'liue',
#   'king',
#   'fran',
#   'barnardo',
#   'bar',
#   'fran',
#   'come',
#   'carefully',
#   'vpon',
#   'houre',
#   'bar',
#   'strook',
#   'twelue',
#   'get',
#   'thee',
#   'bed',
#   'francisco',
#   'fran',
#   'releefe',
#   'much',
#   'thanke',
#   'bitter',
#   'cold',
#   'sicke',
#   'heart',
#   'barn',
#   'haue',
#   'quiet',
#   'guard',
#   'fran',
#   'mouse',
#   'stirring',
#   'barn',
#   'well',
#   'goodnight',
#   'meet',
#   'horatio',
#   'marcellus',
#   'riual',
#   'watch',
#   'bid',
#   'make',
#   'hast',
#   'enter',
#   'horatio',
#   'marcellus',
#   'fran',
#   'thinke',
#   'heare',
#   'stand',
#   'hor',
#   'friend',
#   'ground',
#   'mar',
#   'dane',
#   'fran',
#   'giue',
#   'good_night',
#   'mar',
#   'farwel',
#   'honest',
#   'soldier',
#   'hath',
#   'relieu',
#   'fra',
#   'barnardo',
#   'ha',
#   'place',
#   'giue',
#   'goodnight',
#   'exit',
#   'fran',
#   'mar',
#   'holla',
#   'barnardo',
#   'bar',
#   'horatio',
#   'hor',
#   'peece',
#   'bar',
#   'welcome',
#   'horatio',
#   'welcome',
#   'good',
#   'marcellus',
#   'mar',
#   'ha',
#   'thing',
#   'appear',
#   'againe',
#   'night',
#   'bar',
#   'haue_seene',
#   'nothing',
#   'mar',
#   'horatio',
#   'say',
#   'fantasie',
#   'let',
#   'beleefe',
#   'take',
#   'hold',
#   'touch',
#   'dread',
#   'sight',
#   'twice',
#   'seene',
#   'vs',
#   'therefore',
#   'haue',
#   'intreate',
#   'along',
#   'vs',
#   'watch',
#   'minute',
#   'night',
#   'againe',
#   'apparition',
#   'come',
#   'may',
#   'approue',
#   'eye',
#   'speake',
#   'hor',
#   'tush',
#   'tush',
#   'appeare',
#   'bar',
#   'sit_downe',
#   'let_vs',
#   'againe',
#   'assaile',
#   'eare',
#   'fortified',
#   'story',
#   'two',
#   'night',
#   'haue_seene',
#   'hor',
#   'well',
#   'sit_downe',
#   'let_vs',
#   'heare',
#   'barnardo',
#   'speake',
#   'barn',
#   'last_night',
#   'yond',
#   'starre',
#   'westward',
#   'pole',
#   'make',
#   'course',
#   'illume',
#   'part',
#   'heauen',
#   'burnes',
#   'marcellus',
#   'selfe',
#   'bell',
#   'beat',
#   'one',
#   'mar',
#   'peace',
#   'breake',
#   'thee',
#   'enter_ghost',
#   'looke',
#   'come',
#   'againe',
#   'barn',
#   'figure',
#   'like',
#   'king',
#   'dead',
#   'mar',
#   'thou_art',
#   'scholler',
#   'speake',
#   'horatio',
#   'barn',
#   'looke',
#   'like',
#   'king',
#   'marke',
#   'horatio',
#   'hora',
#   'like',
#   'harrowes',
#   'fear',
#   'wonder',
#   'barn',
#   'speak',
#   'mar',
#   'question',
#   'horatio',
#   'hor',
#   'art_thou',
#   'time',
#   'night',
#   'together',
#   'faire',
#   'warlike',
#   'forme',
#   'maiesty',
#   'bury',
#   'denmarke',
#   'sometimes',
#   'march',
#   'heauen',
#   'charge',
#   'thee',
#   'speake',
#   'mar',
#   'offend',
#   'barn',
#   'see',
#   'stalk',
#   'away',
#   'hor',
#   'stay',
#   'speake',
#   'speake',
#   'charge',
#   'thee',
#   'speake',
#   'exit',
#   'ghost',
#   'mar',
#   'go',
#   'answer',
#   'barn',
#   'horatio',
#   'tremble',
#   'look',
#   'pale',
#   'something',
#   'fantasie',
#   'thinke',
#   'hor',
#   'god',
#   'might',
#   'beleeue',
#   'without',
#   'sensible',
#   'true',
#   'auouch',
#   'mine_owne',
#   'eye',
#   'mar',
#   'like',
#   'king',
#   'hor',
#   'thou_art',
#   'thy_selfe',
#   'armour',
#   'th',
#   'ambitious',
#   'norwey',
#   'combat',
#   'frown',
#   'angry',
#   'parle',
#   'smot',
#   'sledde',
#   'pollax',
#   'ice',
#   'strange',
#   'mar',
#   'thus',
#   'twice',
#   'iust',
#   'dead',
#   'houre',
#   'martiall',
#   'stalke',
#   'hath',
#   'go',
#   'watch',
#   'hor',
#   'particular',
#   'thought',
#   'work',
#   'know',
#   'grosse',
#   'scope',
#   'opinion',
#   'boade',
#   'strange',
#   'erruption',
#   'state',
#   'mar',
#   'good',
#   'sit_downe',
#   'tell',
#   'knowes',
#   'strict',
#   'obseruant',
#   'watch',
#   'nightly',
#   'toyle',
#   'subiect',
#   'land',
#   'dayly',
#   'cast',
#   'brazon',
#   'cannon',
#   'forraigne',
#   'mart',
#   'implement',
#   'warre',
#   'impresse',
#   'whose',
#   'sore',
#   'taske',
#   'diuide',
#   'sunday',
#   'weeke',
#   'might',
#   'toward',
#   'sweaty',
#   'hast',
#   'doth',
#   'make',
#   'night',
#   'day',
#   'informe',
#   'hor',
#   'least',
#   'whisper',
#   'go',
#   'last',
#   'king',
#   'whose',
#   'image',
#   'euen',
#   'appear',
#   'vs',
#   'know',
#   'fortinbras',
#   'norway',
#   'thereto',
#   'prick',
#   'emulate',
#   'pride',
#   'dar',
#   'combate',
#   'valiant',
#   'hamlet',
#   'side',
#   'knowne',
#   'world',
#   'esteem',
#   'slay',
#   'fortinbra',
#   'seal',
#   'compact',
#   'well',
#   'ratify',
#   'law',
#   'heraldrie',
#   'forfeite',
#   'life',
#   'land',
#   'stand',
#   'seiz',
#   'conqueror',
#   'moity',
#   'competent',
#   'gage',
#   'king',
#   'inheritance',
#   'fortinbras',
#   'bin',
#   'vanquisher',
#   'carriage',
#   'article',
#   'designe',
#   'fall',
#   'hamlet',
#   'sir',
#   'young',
#   'fortinbras',
#   'vnimproue',
#   'mettle',
#   'hot',
#   'full',
#   'hath',
#   'skirts',
#   'norway',
#   'heere',
#   'shark',
#   'vp',
#   'list',
#   'landlesse',
#   'resolute',
#   'foode',
#   'diet',
#   'enterprize',
#   'hath',
#   'stomacke',
#   'doth',
#   'well',
#   'appeare',
#   'vnto',
#   'state',
#   'recouer',
#   'vs',
#   'strong',
#   'hand',
#   'term',
#   'compulsatiue',
#   'foresaid',
#   'land',
#   'father',
#   'lose',
#   'take',
#   'maine',
#   'motiue',
#   'preparation',
#   'sourse',
#   'watch',
#   'cheefe',
#   'head',
#   'romage',
#   'land',
#   'enter_ghost',
#   'againe',
#   'soft',
#   'behold',
#   'loe',
#   'come',
#   'againe',
#   'ile',
#   'crosse',
#   'though',
#   'blast',
#   'stay',
#   'illusion',
#   'thou_hast',
#   'sound',
#   'vse',
#   'voyce',
#   'speake',
#   'good',
#   'thing',
#   'do',
#   'may',
#   'thee',
#   'ease',
#   'grace',
#   'speak',
#   'thou_art',
#   'priuy',
#   'thy',
#   'country',
#   'fate',
#   'happily',
#   'foreknow',
#   'may',
#   'auoyd',
#   'oh',
#   'speake',
#   'thou_hast',
#   'thy',
#   'life',
#   'extort',
#   'treasure',
#   'wombe',
#   'earth',
#   'spirit',
#   'oft',
#   'walke',
#   'death',
#   'speake',
#   'stay',
#   'speake',
#   'stop',
#   'marcellus',
#   'mar',
#   'shall',
#   'strike',
#   'partizan',
#   'hor',
#   'stand',
#   'barn',
#   'heere',
#   'hor',
#   'heere',
#   'mar',
#   'go',
#   'exit',
#   'ghost',
#   'wrong',
#   'maiesticall',
#   'offer',
#   'shew',
#   'violence',
#   'ayre',
#   'invulnerable',
#   'vaine',
#   'blowe',
#   'malicious',
#   'mockery',
#   'barn',
#   'speake',
#   'cocke',
#   'crew',
#   'hor',
#   'start',
#   'like',
#   'guilty',
#   'thing',
#   'vpon',
#   'fearfull',
#   'summon',
#   'haue',
#   'hear',
#   'cocke',
#   'trumpet',
#   'day',
#   'doth',
#   'lofty',
#   'throate',
#   'awake',
#   'god',
#   'day',
#   'warn',
#   'whether',
#   'sea',
#   'fire',
#   'earth',
#   'ayre',
#   'th',
#   'extrauagant',
#   'err',
#   'spirit',
#   'hyes',
#   'confine',
#   'truth',
#   'heerein',
#   'present',
#   'obiect',
#   'make',
#   'probation',
#   'mar',
#   'fade',
#   'crow',
#   'cocke',
#   'sayes',
#   'euer',
#   'season',
#   'come',
#   'wherein',
#   'sauiour',
#   'birch',
#   'celebrate',
#   'bird',
#   'dawn',
#   'singeth',
#   'night',
#   'long',
#   'spirit',
#   'walke',
#   'abroad',
#   'night',
#   'wholsome',
#   'planet',
#   'strike',
#   'faiery',
#   'talkes',
#   'witch',
#   'hath',
#   'power',
#   'charme',
#   'hallow',
#   'gracious',
#   'time',
#   'hor',
#   'haue',
#   'hear',
#   'part',
#   'beleeue',
#   'looke',
#   'morne',
#   'russet',
#   'mantle',
#   'clothe',
#   'walk',
#   'dew',
#   'yon',
#   'high',
#   'easterne',
#   'hill',
#   'breake',
#   'watch',
#   'vp',
#   'aduice',
#   'let_vs',
#   'impart',
#   'haue_seene',
#   'night',
#   'vnto',
#   'yong',
#   'hamlet',
#   'vpon',
#   'life',
#   'spirit',
#   'dumbe',
#   'vs',
#   'speake',
#   'consent',
#   'shall',
#   'acquaint',
#   'needfull',
#   'loue',
#   'fitting',
#   'duty',
#   'mar',
#   'let',
#   'pray',
#   'morning',
#   'know',
#   'shall',
#   'finde',
#   'conueniently',
#   'exeunt_scena_secunda',
#   'enter',
#   'claudius',
#   'king',
#   'denmarke',
#   'gertrude',
#   'queene',
#   'hamlet',
#   'polonius',
#   'laerte',
#   'sister',
#   'ophelia',
#   'lords',
#   'attendant',
#   'king',
#   'though',
#   'yet',
#   'hamlet',
#   'deere',
#   'brother',
#   'death',
#   'memory',
#   'greene',
#   'vs',
#   'befit',
#   'beare',
#   'heart',
#   'greefe',
#   'whole',
#   'kingdome',
#   'contract',
#   'one',
#   'brow',
#   'woe',
#   'yet',
#   'farre',
#   'hath',
#   'discretion',
#   'fight',
#   'nature',
#   'wise',
#   'sorrow',
#   'thinke',
#   'together',
#   'remembrance',
#   'selue',
#   'therefore',
#   'sometimes',
#   'sister',
#   'queene',
#   'th',
#   'imperiall',
#   'ioyntresse',
#   'warlike',
#   'state',
#   'haue',
#   'defeat',
#   'ioy',
#   'one',
#   'auspicious',
#   'one',
#   'drop',
#   'eye',
#   'mirth',
#   'funerall',
#   'dirge',
#   'marriage',
#   'equall',
#   'scale',
#   'weigh',
#   'delight',
#   'dole',
#   'take',
#   'wife',
#   'haue',
#   'heerein',
#   'well',
#   'wisedome',
#   'haue',
#   'freely',
#   'go',
#   'affaire',
#   'along',
#   'thanke',
#   'follow',
#   'know',
#   'young',
#   'fortinbra',
#   'hold',
#   'weake',
#   'supposall',
#   'worth',
#   'think',
#   'late',
#   'deere',
#   'brother',
#   'death',
#   'state',
#   'disioynt',
#   'frame',
#   'colleague',
#   'dreame',
#   'aduantage',
#   'hath',
#   'fayl',
#   'pester',
#   'vs',
#   'message',
#   'import',
#   'surrender',
#   'land',
#   'lose',
#   'father',
#   'bond',
#   'law',
#   'valiant',
#   'brother',
#   'much',
#   'enter',
#   'voltemand',
#   'cornelius',
#   'selfe',
#   'time',
#   'meet',
#   'thus',
#   'much',
#   'businesse',
#   'haue',
#   'heere',
#   'writ',
#   'norway',
#   'vncle',
#   'young',
#   'fortinbras',
#   'impotent',
#   'bedrid',
#   'scarsely',
#   'hear',
#   'nephewes',
#   'purpose',
#   'suppresse',
#   'gate',
#   'heerein',
#   'leuies',
#   'list',
#   'full',
#   'proportion',
#   'make',
#   'subiect',
#   'heere',
#   'dispatch',
#   'good',
#   'cornelius',
#   'voltemand',
#   'bear',
#   'greet',
#   'old',
#   'norway',
#   'giue',
#   'personall',
#   'power',
#   'businesse',
#   'king',
#   'scope',
#   'dilate',
#   'article',
#   'allow',
#   'farewell',
#   'let',
#   'hast',
#   'commend',
#   'duty',
#   'volt',
#   'thing',
#   'shew',
#   'duty',
#   'king',
#   'doubt',
#   'nothing',
#   'heartily',
#   'farewell',
#   'exit',
#   'voltemand',
#   'cornelius',
#   'laerte',
#   'newes',
#   'tell',
#   'vs',
#   'suite',
#   'laerte',
#   'speake',
#   'reason',
#   'dane',
#   'loose',
#   'voyce',
#   'thou',
#   'beg',
#   'laerte',
#   'shall',
#   'offer',
#   'thy',
#   'ask',
#   'head',
#   'natiue',
#   'heart',
#   'hand',
#   'instrumentall',
#   'mouth',
#   'throne',
#   'denmarke',
#   'thy',
#   'father',
#   'thou',
#   'haue',
#   'laerte',
#   'laer',
#   'dread',
#   'lord',
#   'leaue',
#   'fauour',
#   'returne',
#   'france',
#   'whence',
#   'though',
#   'willingly',
#   'come',
#   'denmarke',
#   'shew',
#   'duty',
#   'coronation',
#   'yet',
#   'must',
#   'confesse',
#   'duty',
#   'do',
#   'thought',
#   'wish',
#   'bend',
#   'againe',
#   'towards',
#   'france',
#   'bow',
#   'gracious',
#   'leaue',
#   'pardon',
#   'king',
#   'haue',
#   'father',
#   'leaue',
#   'sayes',
#   'pollonius',
#   'pol',
#   'hath',
#   'lord',
#   'beseech',
#   'giue',
#   'leaue',
#   'go',
#   'king',
#   'take',
#   'thy',
#   'faire',
#   'houre',
#   'laerte',
#   'time',
#   'thine',
#   'thy',
#   'good',
#   'grace',
#   'spend',
#   'thy',
#   'cosin',
#   'hamlet',
#   'sonne',
#   'ham',
#   'little',
#   'kin',
#   'lesse',
#   'kinde',
#   'king',
#   'cloud',
#   'still',
#   'hang',
#   'ham',
#   'lord',
#   'much',
#   'sun',
#   'queen',
#   'good',
#   'hamlet',
#   'cast',
#   'thy',
#   'nightly',
#   'colour',
#   'let',
#   'thine',
#   'eye',
#   'looke',
#   'like',
#   'friend',
#   'denmarke',
#   'euer',
#   'thy',
#   'veyle',
#   'lid',
#   'seeke',
#   'thy',
#   'noble',
#   'father',
#   'dust',
#   'thou',
#   'common',
#   'liue',
#   'must',
#   'dye',
#   'pass',
#   'nature',
#   'eternity',
#   'ham',
#   'madam',
#   'common',
#   'queen',
#   'seem',
#   'particular',
#   'thee',
#   'ham',
#   'seemes',
#   'madam',
#   'nay',
#   'know',
#   'seeme',
#   'alone',
#   'inky',
#   'cloake',
#   'good',
#   'mother',
#   'customary',
#   'suit',
#   'solemne',
#   'blacke',
#   'windy',
#   'suspiration',
#   'forc',
#   'breath',
#   'fruitfull',
#   'riuer',
#   'eye',
#   'deiecte',
#   'hauiour',
#   'visage',
#   'together',
#   'form',
#   ...],
#  ['ball',
#   'cross',
#   'chesterton',
#   'discussion',
#   'somewhat',
#   'air',
#   'fly_ship',
#   'professor_lucifer',
#   'sing',
#   'sky',
#   'like',
#   'silver',
#   'arrow',
#   'bleak',
#   'white',
#   'steel',
#   'gleam',
#   'bleak',
#   'blue',
#   'emptiness',
#   'evening',
#   'far',
#   'earth',
#   'expression',
#   'two',
#   'man',
#   'seem',
#   'far',
#   'star',
#   'professor',
#   'invent',
#   'fly',
#   'machine',
#   'also',
#   'invent',
#   'nearly',
#   'everything',
#   'every',
#   'sort',
#   'tool',
#   'apparatus',
#   'consequence',
#   'full',
#   'fantastic',
#   'distorted',
#   'look',
#   'belong',
#   'miracle',
#   'science',
#   'world',
#   'science',
#   'evolution',
#   'far',
#   'nameless',
#   'elusive',
#   'like',
#   'dream',
#   'world',
#   'poetry',
#   'religion',
#   'since',
#   'latter',
#   'image',
#   'idea',
#   'remain',
#   'eternally',
#   'whole',
#   'idea',
#   'evolution',
#   'identity',
#   'melt',
#   'nightmare',
#   'tool',
#   'professor_lucifer',
#   'ancient',
#   'human',
#   'tool',
#   'go',
#   'mad',
#   'grow',
#   'unrecognizable',
#   'shape',
#   'forgetful',
#   'origin',
#   'forgetful',
#   'name',
#   'thing',
#   'look',
#   'like',
#   'enormous',
#   'key',
#   'three',
#   'wheel',
#   'really',
#   'patent',
#   'deadly',
#   'revolver',
#   'object',
#   'seem',
#   'create',
#   'entanglement',
#   'two',
#   'corkscrew',
#   'really',
#   'key',
#   'thing',
#   'might',
#   'mistaken',
#   'tricycle',
#   'turn',
#   'inexpressibly',
#   'important',
#   'instrument',
#   'corkscrew',
#   'key',
#   'thing',
#   'professor',
#   'invent',
#   'invent',
#   'everything',
#   'fly_ship',
#   'exception',
#   'perhaps',
#   'bear',
#   'late',
#   'actually',
#   'inaugurate',
#   'believe',
#   'least',
#   'considerably',
#   'improve',
#   'however',
#   'another',
#   'man',
#   'board',
#   'speak',
#   'time',
#   'also',
#   'curious',
#   'coincidence',
#   'professor',
#   'invent',
#   'even',
#   'greatly',
#   'improve',
#   'though',
#   'fish',
#   'lasso',
#   'back',
#   'garden',
#   'western',
#   'bulgaria',
#   'pure',
#   'object',
#   'improve',
#   'exceedingly',
#   'holy',
#   'man',
#   'almost',
#   'entirely',
#   'cover',
#   'white',
#   'hair',
#   'see',
#   'nothing',
#   'eye',
#   'seem',
#   'talk',
#   'monk',
#   'immense',
#   'learn',
#   'acute',
#   'intellect',
#   'make',
#   'happy',
#   'little',
#   'stone',
#   'hut',
#   'little',
#   'stony',
#   'garden',
#   'balkan',
#   'chiefly',
#   'write',
#   'crush',
#   'refutation',
#   'exposure',
#   'certain',
#   'heresy',
#   'last',
#   'professor',
#   'burn',
#   'generally',
#   'precisely',
#   'year',
#   'previously',
#   'really',
#   'plausible',
#   'thoughtful',
#   'heresy',
#   'really',
#   'creditable',
#   'even',
#   'glorious',
#   'circumstance',
#   'old',
#   'monk',
#   'intellectual',
#   'enough',
#   'detect',
#   'fallacy',
#   'misfortune',
#   'nobody',
#   'modern_world',
#   'intellectual',
#   'enough',
#   'even',
#   'understand',
#   'argument',
#   'old',
#   'monk',
#   'one',
#   'whose',
#   'name',
#   'michael',
#   'name',
#   'quite',
#   'impossible',
#   'remember',
#   'repeat',
#   'western',
#   'civilization',
#   'however',
#   'make',
#   'quite',
#   'happy',
#   'mountain',
#   'hermitage',
#   'society',
#   'wild',
#   'animal',
#   'luck',
#   'lift',
#   'mountain',
#   'society',
#   'wild',
#   'physicist',
#   'make',
#   'happy',
#   'still',
#   'intention',
#   'good',
#   'michael',
#   'professor_lucifer',
#   'endeavour',
#   'convert',
#   'argument',
#   'imbecility',
#   'tradition',
#   'quite',
#   'finally',
#   'exhibit',
#   'anybody',
#   'mere',
#   'ordinary',
#   'knowledge_world',
#   'kind',
#   'knowledge',
#   'teach',
#   'we',
#   'sit',
#   'draught',
#   'encourage',
#   'friendliness',
#   'impecunious',
#   'people',
#   'folly',
#   'talk',
#   'demonstrate',
#   'rationalist',
#   'philosophy',
#   'everything',
#   'demonstrate',
#   'rub',
#   'shoulder',
#   'man',
#   'kind',
#   'forgive',
#   'monk',
#   'meekly',
#   'loads',
#   'white',
#   'beard',
#   'fear',
#   'understand',
#   'order',
#   'might',
#   'rub',
#   'shoulder',
#   'man',
#   'kind',
#   'put',
#   'inside',
#   'thing',
#   'entertain',
#   'retort',
#   'narrow',
#   'deductive',
#   'manner',
#   'middle',
#   'age',
#   'reply',
#   'professor',
#   'calmly',
#   'even',
#   'upon',
#   'basis',
#   'illustrate',
#   'point',
#   'sky',
#   'religion',
#   'religion',
#   'far',
#   'know',
#   'know',
#   'everything',
#   'sky',
#   'make',
#   'symbol',
#   'everything',
#   'sacred',
#   'merciful',
#   'well',
#   'sky',
#   'know',
#   'well',
#   'phrase',
#   'like',
#   'twist',
#   'like',
#   'know',
#   'know',
#   'well',
#   'know',
#   'man',
#   'real',
#   'feeling',
#   'heaven',
#   'find',
#   'alone',
#   'heaven',
#   'surround',
#   'heaven',
#   'know',
#   'truth',
#   'truth',
#   'heavens',
#   'evil',
#   'sky',
#   'evil',
#   'star',
#   'evil',
#   'mere',
#   'space',
#   'mere',
#   'quantity',
#   'terrify',
#   'man',
#   'tiger',
#   'terrible',
#   'plague',
#   'know',
#   'since',
#   'science',
#   'speak',
#   'bottom',
#   'fall',
#   'universe',
#   'heaven',
#   'hopeless',
#   'thing',
#   'hopeless',
#   'hell',
#   'comfort',
#   'miserable',
#   'progeny',
#   'morbid',
#   'ape',
#   'must',
#   'earth',
#   'underneath',
#   'root',
#   'grass',
#   'place',
#   'hell',
#   'old',
#   'fiery',
#   'crypt',
#   'lurid',
#   'cellar',
#   'underworld',
#   'condemn',
#   'wicked',
#   'hideous',
#   'enough',
#   'least',
#   'homely',
#   'heaven',
#   'ride',
#   'time',
#   'come',
#   'hide',
#   'escape',
#   'horror',
#   'star',
#   'hope',
#   'excuse',
#   'interrupt',
#   'michael',
#   'slight',
#   'cough',
#   'always',
#   'notice',
#   'go',
#   'pray',
#   'go',
#   'professor_lucifer',
#   'radiantly',
#   'really',
#   'like',
#   'draw',
#   'simple',
#   'idea',
#   'well',
#   'fact',
#   'much',
#   'admire',
#   'rhetoric',
#   'rhetoric',
#   'school',
#   'purely',
#   'verbal',
#   'point_view',
#   'little',
#   'study',
#   'school',
#   'human',
#   'history',
#   'enable',
#   'make',
#   'lead',
#   'er',
#   'rather',
#   'singular',
#   'conclusion',
#   'find',
#   'great',
#   'difficulty',
#   'express',
#   'especially',
#   'foreign',
#   'language',
#   'come',
#   'come',
#   'professor',
#   'encouragingly',
#   'help',
#   'view',
#   'strike',
#   'well',
#   'truth',
#   'know',
#   'express',
#   'properly',
#   'somehow',
#   'seem',
#   'always',
#   'convey',
#   'idea',
#   'kind',
#   'eloquence',
#   'er',
#   'oh',
#   'get',
#   'cry',
#   'lucifer',
#   'boisterously',
#   'well',
#   'point',
#   'fact',
#   'fly_ship',
#   'going',
#   'run',
#   'something',
#   'think',
#   'mind',
#   'mention',
#   'run',
#   'something',
#   'lucifer',
#   'explode',
#   'oath',
#   'leapt',
#   'erect',
#   'lean',
#   'hard',
#   'upon',
#   'handle',
#   'act',
#   'helm',
#   'vessel',
#   'last',
#   'ten_minute',
#   'shoot',
#   'downwards',
#   'great',
#   'crack',
#   'cavern',
#   'cloud',
#   'sort',
#   'purple',
#   'haze',
#   'see',
#   'comparatively',
#   'near',
#   'seem',
#   'upper',
#   'part',
#   'huge',
#   'dark',
#   'orb',
#   'sphere',
#   'islande',
#   'sea',
#   'cloud',
#   'professor',
#   'eye',
#   'blaze',
#   'like',
#   'maniac',
#   'new',
#   'world',
#   'cry',
#   'dreadful',
#   'mirth',
#   'new',
#   'planet',
#   'shall',
#   'bear',
#   'name',
#   'star',
#   'vulgar',
#   'one',
#   'shall',
#   'sun',
#   'morning',
#   'charter',
#   'lunacy',
#   'god',
#   'man',
#   'shall',
#   'innocent',
#   'daisy',
#   'innocent',
#   'cruel',
#   'intellect',
#   'seem',
#   'michael',
#   'timidly',
#   'something',
#   'stick',
#   'middle',
#   'professor',
#   'lean',
#   'side',
#   'ship',
#   'spectacle',
#   'shine',
#   'intellectual',
#   'excitement',
#   'might',
#   'course',
#   'merely',
#   'shriek',
#   'indescribable',
#   'break',
#   'sudden',
#   'flung',
#   'arm',
#   'like',
#   'lose',
#   'spirit',
#   'monk',
#   'take',
#   'helm',
#   'tired',
#   'way',
#   'seem',
#   'much',
#   'astonished',
#   'come',
#   'ignorant',
#   'part',
#   'world',
#   'uncommon',
#   'lose',
#   'spirit',
#   'shriek',
#   'see',
#   'curious',
#   'shape',
#   'professor',
#   'see',
#   'top',
#   'mysterious',
#   'ball',
#   'take',
#   'helm',
#   'time',
#   'drive',
#   'hard',
#   'left',
#   'prevent',
#   'fly_ship',
#   'smash',
#   'cathedral',
#   'plain',
#   'cloud',
#   'lie',
#   'along',
#   'level',
#   'top',
#   'cathedral',
#   'dome',
#   'ball',
#   'cross',
#   'look',
#   'like',
#   'buoy',
#   'ride',
#   'leaden',
#   'sea',
#   'fly_ship',
#   'sweep',
#   'towards',
#   'plain',
#   'cloud',
#   'look',
#   'dry',
#   'definite',
#   'rocky',
#   'grey',
#   'desert',
#   'hence',
#   'give',
#   'mind',
#   'body',
#   'sharp',
#   'unearthly',
#   'sensation',
#   'ship',
#   'cut',
#   'sank',
#   'cloud',
#   'common',
#   'mist',
#   'thing',
#   'without',
#   'resistance',
#   'deadly',
#   'shock',
#   'fact',
#   'shock',
#   'cleave',
#   'ancient',
#   'cliff',
#   'like',
#   'much',
#   'butter',
#   'sensation',
#   'await',
#   'much',
#   'strange',
#   'sink',
#   'solid',
#   'earth',
#   'moment',
#   'eye',
#   'nostril',
#   'stop',
#   'darkness',
#   'opaque',
#   'cloud',
#   'darkness',
#   'warm',
#   'kind',
#   'brown',
#   'fog',
#   'far',
#   'far',
#   'brown',
#   'fog',
#   'fall',
#   'warm',
#   'fire',
#   'dense',
#   'london',
#   'atmosphere',
#   'see',
#   'flame',
#   'london',
#   'light',
#   'light',
#   'lie',
#   'beneath',
#   'square',
#   'oblongs',
#   'fire',
#   'fog',
#   'fire',
#   'mixed',
#   'passionate',
#   'vapour',
#   'might',
#   'fog',
#   'drown',
#   'flame',
#   'might',
#   'flame',
#   'set',
#   'fog',
#   'fire',
#   'beside',
#   'ship',
#   'beneath',
#   'swung',
#   'ball',
#   'immeasurable',
#   'dome',
#   'shoot',
#   'dark',
#   'like',
#   'combination',
#   'voiceless',
#   'cataract',
#   'like',
#   'cyclopean',
#   'sit',
#   'london',
#   'let',
#   'tentacle',
#   'bewilderingly',
#   'every',
#   'side',
#   'monstrosity',
#   'starless',
#   'heaven',
#   'cloud',
#   'belong',
#   'london',
#   'close',
#   'head',
#   'voyager',
#   'seal',
#   'entrance',
#   'upper',
#   'air',
#   'break',
#   'roof',
#   'come',
#   'temple',
#   'twilight',
#   'near',
#   'ball',
#   'lucifer',
#   'lean',
#   'hand',
#   'hold',
#   'vessel',
#   'away',
#   'man',
#   'push',
#   'boat',
#   'bank',
#   'cross',
#   'already',
#   'drape',
#   'dark',
#   'mist',
#   'borderland',
#   'shadowy',
#   'awful',
#   'shape',
#   'size',
#   'professor_lucifer',
#   'slap',
#   'hand',
#   'twice',
#   'upon',
#   'surface',
#   'great',
#   'orb',
#   'caress',
#   'enormous',
#   'animal',
#   'fellow',
#   'one',
#   'money',
#   'may',
#   'respect',
#   'inquire',
#   'ask',
#   'old',
#   'monk',
#   'earth',
#   'talking',
#   'cry',
#   'lucifer',
#   'smite',
#   'ball',
#   'symbol',
#   'boy',
#   'fat',
#   'satisfied',
#   'like',
#   'scraggy',
#   'individual',
#   'stretch',
#   'arm',
#   'stark',
#   'weariness',
#   'point',
#   'cross',
#   'face',
#   'dark',
#   'grin',
#   'tell',
#   'michael',
#   'prove',
#   'good',
#   'part',
#   'rationalist',
#   'case',
#   'christian',
#   'humbug',
#   'symbol',
#   'like',
#   'give',
#   'instance',
#   'come',
#   'across',
#   'instance',
#   'vengeance',
#   'possibly',
#   'express',
#   'philosophy',
#   'philosophy',
#   'well',
#   'shape',
#   'cross',
#   'shape',
#   'ball',
#   'globe',
#   'reasonable',
#   'cross',
#   'unreasonable',
#   'animal',
#   'one',
#   'leg',
#   'long',
#   'other',
#   'globe',
#   'inevitable',
#   'cross',
#   'arbitrary',
#   'globe',
#   'unity',
#   'cross',
#   'primarily',
#   'thing',
#   'enmity',
#   'cross',
#   'conflict',
#   'two',
#   'hostile',
#   'line',
#   'irreconcilable',
#   'direction',
#   'silent',
#   'thing',
#   'essentially',
#   'collision',
#   'crash',
#   'struggle',
#   'stone',
#   'pah',
#   'sacred',
#   'symbol',
#   'actually',
#   'give',
#   'name',
#   'description',
#   'desperation',
#   'muddle',
#   'speak',
#   'man',
#   'ignorant',
#   'frustrated',
#   'away',
#   'thing',
#   'shape',
#   'contradiction',
#   'term',
#   'perfectly',
#   'true',
#   'michael',
#   'serenity',
#   'like',
#   'contradiction',
#   'term',
#   'man',
#   'contradiction',
#   'term',
#   'beast',
#   'whose',
#   'superiority',
#   'beast',
#   'consist',
#   'fall',
#   'cross',
#   'eternal',
#   'collision',
#   'struggle',
#   'stone',
#   'every',
#   'form',
#   'life',
#   'struggle',
#   'flesh',
#   'shape',
#   'cross',
#   'irrational',
#   'shape',
#   'human',
#   'animal',
#   'irrational',
#   'cross',
#   'quadrupe',
#   'one',
#   'limb',
#   'long',
#   'rest',
#   'man',
#   'quadrupe',
#   'use',
#   'two',
#   'leg',
#   'professor',
#   'frown',
#   'thoughtfully',
#   'instant',
#   'course',
#   'everything',
#   'relative',
#   'deny',
#   'element',
#   'struggle',
#   'represent',
#   'cross',
#   'necessary',
#   'place',
#   'certain',
#   'evolutionary',
#   'stage',
#   'surely',
#   'cross',
#   'low',
#   'development',
#   'sphere',
#   'higher',
#   'easy',
#   'enough',
#   'see',
#   'really',
#   'wrong',
#   'wren',
#   'architectural',
#   'arrangement',
#   'pray',
#   'inquire',
#   'michael',
#   'meekly',
#   'cross',
#   'top',
#   'ball',
#   'professor_lucifer',
#   'simply',
#   'surely',
#   'wrong',
#   'ball',
#   ...]]

# %%
# create the dictionary of the new corpus
dictionary = corpora.Dictionary(documents)
dictionary.save_as_text("new_dictionary.txt")

# %%
# transform it into bag of words
corpus = [dictionary.doc2bow(text) for text in documents]
# print the new form of our corpus
for doc in corpus:
    print(doc)

print(len(dictionary))
# Out:
# [(0, 15), (1, 1), (2, 1), (3, 2), (4, 1), (5, 3), (6, 65), (7, 6), (8, 1), (9, 1), (10, 7), (11, 8), (12, 3), (13, 5), (14, 1), (15, 16), (16, 10), (17, 1), (18, 2), (19, 4), (20, 33), (21, 1), (22, 1), (23, 1), (24, 3), (25, 5), (26, 1), (27, 1), (28, 2), (29, 1), (30, 1), (31, 6), (32, 28), (33, 8), (34, 2), (35, 1), (36, 1), (37, 3), (38, 2), (39, 2), (40, 8), (41, 1), (42, 9), (43, 11), (44, 2), (45, 3), (46, 6), (47, 1), (48, 4), (49, 1), (50, 60), (51, 1), (52, 1), (53, 1), (54, 2), (55, 1), (56, 2), (57, 1), (58, 1), (59, 2), (60, 1), (61, 31), (62, 6), (63, 26), (64, 56), (65, 7), (66, 1), (67, 5), (68, 4), (69, 2), (70, 7), (71, 1), (72, 1), (73, 3), (74, 1), (75, 1), (76, 25), (77, 1), (78, 7), (79, 7), (80, 4), (81, 3), (82, 29), (83, 2), (84, 1), (85, 2), (86, 49), (87, 10), (88, 4), (89, 23), (90, 2), (91, 2), (92, 1), (93, 1), (